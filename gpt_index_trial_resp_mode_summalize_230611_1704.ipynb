# %% [markdown]
# <a href="https://colab.research.google.com/github/ryogrid/ryogridJupyterNotebooks/blob/master/gpt_index_trial_resp_mode_summalize_230611_1704.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/gpt-index-trial
# Out:
# /content/drive/MyDrive/gpt-index-trial

# %%
# !cat requirements.txt
# Out:
# llama-index
# langchain
# transformers
# sentence-transformers
# sentencepiece

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting llama-index (from -r requirements.txt (line 1))
#   Downloading llama_index-0.6.22-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.5/493.5 kB 18.7 MB/s eta 0:00:00
# Collecting langchain (from -r requirements.txt (line 2))
#   Downloading langchain-0.0.196-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.8 MB/s eta 0:00:00
# Collecting transformers (from -r requirements.txt (line 3))
#   Downloading transformers-4.30.1-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 91.3 MB/s eta 0:00:00
# Collecting sentence-transformers (from -r requirements.txt (line 4))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece (from -r requirements.txt (line 5))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.8 MB/s eta 0:00:00
# Collecting dataclasses-json (from llama-index->-r requirements.txt (line 1))
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting sqlalchemy>=2.0.15 (from llama-index->-r requirements.txt (line 1))
#   Downloading SQLAlchemy-2.0.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 105.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index->-r requirements.txt (line 1)) (8.2.2)
# Collecting openai>=0.26.4 (from llama-index->-r requirements.txt (line 1))
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: urllib3<2 in /usr/local/lib/python3.10/dist-packages (from llama-index->-r requirements.txt (line 1)) (1.26.15)
# Collecting fsspec>=2023.5.0 (from llama-index->-r requirements.txt (line 1))
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 23.3 MB/s eta 0:00:00
# Collecting typing-inspect==0.8.0 (from llama-index->-r requirements.txt (line 1))
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: typing-extensions==4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index->-r requirements.txt (line 1)) (4.5.0)
# Collecting tiktoken (from llama-index->-r requirements.txt (line 1))
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 91.1 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0 (from typing-inspect==0.8.0->llama-index->-r requirements.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (6.0)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain->-r requirements.txt (line 2))
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain->-r requirements.txt (line 2))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting langchainplus-sdk>=0.0.7 (from langchain->-r requirements.txt (line 2))
#   Downloading langchainplus_sdk-0.0.8-py3-none-any.whl (22 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.8.4)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain->-r requirements.txt (line 2))
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (1.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r requirements.txt (line 3))
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 3))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 3))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 3)) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2))
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.4 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2))
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2))
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json->llama-index->-r requirements.txt (line 1))
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 6.7 MB/s eta 0:00:00
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json->llama-index->-r requirements.txt (line 1))
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0.15->llama-index->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (16.0.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->-r requirements.txt (line 4)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers->-r requirements.txt (line 4)) (8.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers->-r requirements.txt (line 4)) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=2a47ac184a818a875079e375d7297bf82c2d6c8fb8249218626434ae3da0e1b8
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, sqlalchemy, mypy-extensions, multidict, marshmallow, fsspec, frozenlist, async-timeout, yarl, typing-inspect, tiktoken, openapi-schema-pydantic, marshmallow-enum, langchainplus-sdk, huggingface-hub, aiosignal, transformers, dataclasses-json, aiohttp, openai, langchain, llama-index, sentence-transformers
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 dataclasses-json-0.5.7 frozenlist-1.3.3 fsspec-2023.6.0 huggingface-hub-0.15.1 langchain-0.0.196 langchainplus-sdk-0.0.8 llama-index-0.6.22 marshmallow-3.19.0 marshmallow-enum-1.5.1 multidict-6.0.4 mypy-extensions-1.0.0 openai-0.27.8 openapi-schema-pydantic-1.2.4 safetensors-0.3.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 sqlalchemy-2.0.16 tiktoken-0.4.0 tokenizers-0.13.3 transformers-4.30.1 typing-inspect-0.8.0 yarl-1.9.2

# %%
from llama_index import LLMPredictor
from langchain.llms.base import LLM
from typing import Optional, List, Mapping, Any

# %%
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/gpt-index-trial
# requirements.txt

# %%
DEFAULT_PROMPT = """
文脈情報は以下です。
---
{context_str}
---
事前知識ではなく、文脈情報を参考に質問に答えてください。：{query_str}
"""

REFINE_PROMPT = """
質問は以下です。：{query_str}
すでに答えの候補があります。：{existing_answer}
必要な場合のみ、以下の文脈情報を使ってこの答えを改良することができます。
---
{context_msg}
---
この文脈情報により、元の答えを改良して質問に答えてください。
文脈情報が有用でない場合は元の答えをそのまま返してください。
"""

# %%
import torch
from transformers import T5Tokenizer, AutoModelForCausalLM

tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt-1b")
qa_model = AutoModelForCausalLM.from_pretrained("oshizo/qa-refine-japanese-gpt-1b")

if torch.cuda.is_available():
    qa_model = qa_model.to("cuda")
# Out:
# Downloading spiece.model:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/153 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.63G [00:00<?, ?B/s]

# %%
def generate(prompt):

    token_ids = tokenizer.encode(prompt, add_special_tokens=False, return_tensors="pt")
    n = len(token_ids[0])

    with torch.no_grad():
        output_ids = qa_model.generate(
            token_ids.to(qa_model.device),
            max_length=n+100,
            min_length=n+2,
            do_sample=False,
            pad_token_id=tokenizer.pad_token_id,
            bos_token_id=tokenizer.bos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )
    output = tokenizer.decode(output_ids.tolist()[0][n:])
    return output.replace("</s>", "")

# %%
class CustomLLM(LLM):
        
    @property
    def _llm_type(self) -> str:
        return "custom"
    
    def _call(self, prompt: str, stop: Optional[List[str]] = None) -> str:
        return generate(prompt)
    @property
    def _identifying_params(self) -> Mapping[str, Any]:
        return {"name":"custom"}
llm = CustomLLM()
llm_predictor = LLMPredictor(llm=llm)
# llm_predictor = LLMPredictor(llm)

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index import LangchainEmbedding

# load in HF embedding model from langchain
embed_model = LangchainEmbedding(HuggingFaceEmbeddings(model_name="oshizo/sbert-jsnli-luke-japanese-base-lite"))
embed_model._langchain_embedding.client.max_seq_length = 256
# Out:
# Downloading (…)4f656/.gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)36cd14f656/README.md:   0%|          | 0.00/3.00k [00:00<?, ?B/s]
# Downloading (…)56/added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# Downloading (…)cd14f656/config.json:   0%|          | 0.00/868 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading (…)56/entity_vocab.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/532M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# Downloading (…)d14f656/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
import urllib
import json
url = "https://ja.wikipedia.org/wiki/%E3%81%BC%E3%81%A3%E3%81%A1%E3%83%BB%E3%81%96%E3%83%BB%E3%82%8D%E3%81%A3%E3%81%8F!?action=cirrusdump"
with urllib.request.urlopen(url) as f:
    data = f.read()
text = json.loads(data)[0]["_source"]["text"]

# %%
# OpenAIのAPIは呼び出さないがapi keyが設定されていないとインデックス作成時にエラーになる
# ため、空文字を設定している
! export OPENAI_API_KEY=""

# %%
from typing import Dict
from llama_index.callbacks.base import BaseCallbackHandler
from llama_index.callbacks.schema import CBEventType

class CustomCallbackHandler(BaseCallbackHandler):

    def __init__(
        self,
        event_starts_to_ignore: Optional[List[CBEventType]] = None,
        event_ends_to_ignore: Optional[List[CBEventType]] = None,
        print_trace_on_end: bool = True,
    ) -> None:
        event_starts_to_ignore = event_starts_to_ignore if event_starts_to_ignore else []
        event_ends_to_ignore = event_ends_to_ignore if event_ends_to_ignore else []
        super().__init__(
            event_starts_to_ignore=event_starts_to_ignore,
            event_ends_to_ignore=event_ends_to_ignore,
        )

    def on_event_start(
        self,
        event_type: CBEventType,
        payload: Optional[Dict[str, Any]] = None,
        event_id: str = "",
        **kwargs: Any
    ) -> str:
        print(f"event_type = {event_type} (start)")
        return event_id

    def on_event_end(
        self,
        event_type: CBEventType,
        payload: Optional[Dict[str, Any]] = None,
        event_id: str = "",
        **kwargs: Any
    ) -> None:
        print(f"event_type = {event_type} (end)")
        if event_type == CBEventType.RETRIEVE:
          for selected_node in payload["nodes"]:
            print(selected_node)

    def start_trace(self, trace_id: Optional[str] = None) -> None:
        print("start_trace")

    def end_trace(
        self,
        trace_id: Optional[str] = None,
        trace_map: Optional[Dict[str, List[str]]] = None,
    ) -> None:
        print("end_trace")

# %%
#from llama_index import GPTVectorStoreIndex
from llama_index import LLMPredictor, ServiceContext, GPTSimpleKeywordTableIndex, VectorStoreIndex
from llama_index.readers.schema.base import Document
from llama_index.indices.list.base import ListRetrieverMode
from llama_index.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.indices.service_context import set_global_service_context
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.indices.query.response_synthesis import ResponseSynthesizer
from llama_index.indices.response.type import ResponseMode
from llama_index.indices.prompt_helper import PromptHelper

documents = []
for i in range(0, len(text), 200):
    documents.append(Document(text[i:i+200]))
    if i != 0:
        documents.append(Document(text[i-100:i+100]))

#llm_predictor   = LLMPredictor(llm=llm)
llama_debug_handler = LlamaDebugHandler()
custom_callback_handler = CustomCallbackHandler()
callback_manager = CallbackManager([
    llama_debug_handler
    , custom_callback_handler
])
#callback_manager = CallbackManager([llama_debug_handler])

service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor, callback_manager=callback_manager, embed_model=embed_model, prompt_helper=PromptHelper.from_llm_metadata(llm_predictor.get_llm_metadata()))
#set_global_service_context(service_context=service_context)
#service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)

# インデックスの作成
#index = GPTVectorStoreIndex.from_documents(documents, llm_predictor=llm_predictor, embed_model=embed_model)
#index = GPTSimpleKeywordTableIndex.from_documents(documents, service_context=service_context, llm_predictor=llm_predictor, embed_model=embed_model)
index = VectorStoreIndex.from_documents(documents, service_context=service_context, llm_predictor=llm_predictor, embed_model=embed_model)
# Out:
# start_trace
# event_type = node_parsing (start)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = chunking (start)
# event_type = chunking (end)
# event_type = node_parsing (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = embedding (start)
# event_type = embedding (end)
# **********
# Trace: index_construction
#     |_node_parsing ->  0.313607 seconds
#       |_chunking ->  0.001255 seconds
#       |_chunking ->  0.001351 seconds
#       |_chunking ->  0.001075 seconds
#       |_chunking ->  0.001034 seconds
#       |_chunking ->  0.000881 seconds
#       |_chunking ->  0.001053 seconds
#       |_chunking ->  0.000962 seconds
#       |_chunking ->  0.000934 seconds
#       |_chunking ->  0.00102 seconds
#       |_chunking ->  0.001035 seconds
#       |_chunking ->  0.000916 seconds
#       |_chunking ->  0.000694 seconds
#       |_chunking ->  0.000992 seconds
#       |_chunking ->  0.000985 seconds
#       |_chunking ->  0.000952 seconds
#       |_chunking ->  0.001033 seconds
#       |_chunking ->  0.000925 seconds
#       |_chunking ->  0.000922 seconds
#       |_chunking ->  0.000869 seconds
#       |_chunking ->  0.000933 seconds
#       |_chunking ->  0.001057 seconds
#       |_chunking ->  0.000972 seconds
#       |_chunking ->  0.001003 seconds
#       |_chunking ->  0.00113 seconds
#       |_chunking ->  0.000911 seconds
#       |_chunking ->  0.00089 seconds
#       |_chunking ->  0.001074 seconds
#       |_chunking ->  0.000867 seconds
#       |_chunking ->  0.000904 seconds
#       |_chunking ->  0.000938 seconds
#       |_chunking ->  0.000883 seconds
#       |_chunking ->  0.000915 seconds
#       |_chunking ->  0.000863 seconds
#       |_chunking ->  0.001059 seconds
#       |_chunking ->  0.001091 seconds
#       |_chunking ->  0.001096 seconds
#       |_chunking ->  0.001022 seconds
#       |_chunking ->  0.001017 seconds
#       |_chunking ->  0.000969 seconds
#       |_chunking ->  0.001044 seconds
#       |_chunking ->  0.001125 seconds
#       |_chunking ->  0.001071 seconds
#       |_chunking ->  0.001065 seconds
#       |_chunking ->  0.00104 seconds
#       |_chunking ->  0.001048 seconds
#       |_chunking ->  0.001134 seconds
#       |_chunking ->  0.001147 seconds
#       |_chunking ->  0.001292 seconds
#       |_chunking ->  0.001174 seconds
#       |_chunking ->  0.001013 seconds
#       |_chunking ->  0.001026 seconds
#       |_chunking ->  0.001054 seconds
#       |_chunking ->  0.001039 seconds
#       |_chunking ->  0.00108 seconds
#       |_chunking ->  0.001037 seconds
#       |_chunking ->  0.00102 seconds
#       |_chunking ->  0.001054 seconds
#       |_chunking ->  0.001052 seconds
#       |_chunking ->  0.000993 seconds
#       |_chunking ->  0.001136 seconds
#       |_chunking ->  0.001115 seconds
#       |_chunking ->  0.001018 seconds
#       |_chunking ->  0.00108 seconds
#       |_chunking ->  0.000973 seconds
#       |_chunking ->  0.001033 seconds
#       |_chunking ->  0.001042 seconds
#       |_chunking ->  0.001049 seconds
#       |_chunking ->  0.001027 seconds
#       |_chunking ->  0.001045 seconds
#       |_chunking ->  0.000989 seconds
#       |_chunking ->  0.001015 seconds
#       |_chunking ->  0.001132 seconds
#       |_chunking ->  0.001098 seconds
#       |_chunking ->  0.000978 seconds
#       |_chunking ->  0.001078 seconds
#       |_chunking ->  0.001037 seconds
#       |_chunking ->  0.001002 seconds
#       |_chunking ->  0.001051 seconds
#       |_chunking ->  0.001024 seconds
#       |_chunking ->  0.001039 seconds
#       |_chunking ->  0.001025 seconds
#       |_chunking ->  0.001115 seconds
#       |_chunking ->  0.001053 seconds
#       |_chunking ->  0.001001 seconds
#       |_chunking ->  0.000963 seconds
#       |_chunking ->  0.001113 seconds
#       |_chunking ->  0.001187 seconds
#       |_chunking ->  0.00102 seconds
#       |_chunking ->  0.001033 seconds
#       |_chunking ->  0.001072 seconds
#       |_chunking ->  0.001086 seconds
#       |_chunking ->  0.00105 seconds
#       |_chunking ->  0.001059 seconds
#       |_chunking ->  0.001108 seconds
#       |_chunking ->  0.001107 seconds
#       |_chunking ->  0.00104 seconds
#       |_chunking ->  0.001017 seconds
#       |_chunking ->  0.00103 seconds
#       |_chunking ->  0.001047 seconds
#       |_chunking ->  0.001097 seconds
#       |_chunking ->  0.00154 seconds
#       |_chunking ->  0.00122 seconds
#       |_chunking ->  0.001129 seconds
#       |_chunking ->  0.001076 seconds
#       |_chunking ->  0.001128 seconds
#       |_chunking ->  0.001079 seconds
#       |_chunking ->  0.001006 seconds
#       |_chunking ->  0.001014 seconds
#       |_chunking ->  0.001184 seconds
#       |_chunking ->  0.001044 seconds
#       |_chunking ->  0.000856 seconds
#       |_chunking ->  0.000712 seconds
#       |_chunking ->  0.000937 seconds
#       |_chunking ->  0.001071 seconds
#       |_chunking ->  0.00098 seconds
#       |_chunking ->  0.001056 seconds
#       |_chunking ->  0.00109 seconds
#       |_chunking ->  0.001046 seconds
#       |_chunking ->  0.000993 seconds
#       |_chunking ->  0.000909 seconds
#       |_chunking ->  0.001107 seconds
#       |_chunking ->  0.001098 seconds
#       |_chunking ->  0.001103 seconds
#       |_chunking ->  0.001008 seconds
#       |_chunking ->  0.001047 seconds
#       |_chunking ->  0.001001 seconds
#       |_chunking ->  0.001041 seconds
#       |_chunking ->  0.000906 seconds
#       |_chunking ->  0.001056 seconds
#       |_chunking ->  0.000966 seconds
#       |_chunking ->  0.000914 seconds
#       |_chunking ->  0.000959 seconds
#       |_chunking ->  0.000939 seconds
#       |_chunking ->  0.001003 seconds
#       |_chunking ->  0.00106 seconds
#       |_chunking ->  0.001114 seconds
#       |_chunking ->  0.000996 seconds
#       |_chunking ->  0.001044 seconds
#       |_chunking ->  0.001118 seconds
#       |_chunking ->  0.001013 seconds
#       |_chunking ->  0.000882 seconds
#       |_chunking ->  0.001008 seconds
#       |_chunking ->  0.000934 seconds
#       |_chunking ->  0.00117 seconds
#       |_chunking ->  0.001101 seconds
#       |_chunking ->  0.001021 seconds
#       |_chunking ->  0.00111 seconds
#       |_chunking ->  0.001127 seconds
#       |_chunking ->  0.001074 seconds
#       |_chunking ->  0.001032 seconds
#       |_chunking ->  0.001227 seconds
#       |_chunking ->  0.000947 seconds
#       |_chunking ->  0.001 seconds
#       |_chunking ->  0.000991 seconds
#       |_chunking ->  0.000903 seconds
#       |_chunking ->  0.000989 seconds
#       |_chunking ->  0.000988 seconds
#       |_chunking ->  0.000924 seconds
#       |_chunking ->  0.001075 seconds
#       |_chunking ->  0.000997 seconds
#       |_chunking ->  0.001023 seconds
#       |_chunking ->  0.001062 seconds
#       |_chunking ->  0.001015 seconds
#       |_chunking ->  0.001048 seconds
#       |_chunking ->  0.001034 seconds
#       |_chunking ->  0.001119 seconds
#       |_chunking ->  0.001495 seconds
#       |_chunking ->  0.001597 seconds
#       |_chunking ->  0.002016 seconds
#       |_chunking ->  0.001928 seconds
#       |_chunking ->  0.001227 seconds
#       |_chunking ->  0.001214 seconds
#       |_chunking ->  0.001012 seconds
#       |_chunking ->  0.001059 seconds
#       |_chunking ->  0.00101 seconds
#       |_chunking ->  0.001068 seconds
#       |_chunking ->  0.001083 seconds
#       |_chunking ->  0.001055 seconds
#       |_chunking ->  0.001066 seconds
#       |_chunking ->  0.001112 seconds
#       |_chunking ->  0.001093 seconds
#       |_chunking ->  0.001056 seconds
#       |_chunking ->  0.000963 seconds
#       |_chunking ->  0.001101 seconds
#       |_chunking ->  0.001017 seconds
#       |_chunking ->  0.001161 seconds
#       |_chunking ->  0.001086 seconds
#       |_chunking ->  0.001052 seconds
#       |_chunking ->  0.000995 seconds
#       |_chunking ->  0.00108 seconds
#       |_chunking ->  0.001048 seconds
#       |_chunking ->  0.000997 seconds
#       |_chunking ->  0.001006 seconds
#       |_chunking ->  0.001056 seconds
#       |_chunking ->  0.001044 seconds
#       |_chunking ->  0.000997 seconds
#       |_chunking ->  0.001423 seconds
#       |_chunking ->  0.00128 seconds
#       |_chunking ->  0.001122 seconds
#       |_chunking ->  0.001116 seconds
#       |_chunking ->  0.001176 seconds
#       |_chunking ->  0.001336 seconds
#       |_chunking ->  0.001114 seconds
#       |_chunking ->  0.00114 seconds
#       |_chunking ->  0.001326 seconds
#       |_chunking ->  0.001565 seconds
#       |_chunking ->  0.001403 seconds
#       |_chunking ->  0.001448 seconds
#       |_chunking ->  0.001112 seconds
#       |_chunking ->  0.001202 seconds
#       |_chunking ->  0.001193 seconds
#       |_chunking ->  0.001242 seconds
#       |_chunking ->  0.00125 seconds
#       |_chunking ->  0.001159 seconds
#       |_chunking ->  0.00111 seconds
#       |_chunking ->  0.001138 seconds
#       |_chunking ->  0.001146 seconds
#       |_chunking ->  0.00108 seconds
#       |_chunking ->  0.001094 seconds
#       |_chunking ->  0.001148 seconds
#       |_chunking ->  0.001104 seconds
#       |_chunking ->  0.001144 seconds
#       |_chunking ->  0.001256 seconds
#       |_chunking ->  0.001266 seconds
#       |_chunking ->  0.001239 seconds
#       |_chunking ->  0.001205 seconds
#       |_chunking ->  0.001234 seconds
#       |_chunking ->  0.001247 seconds
#       |_chunking ->  0.001192 seconds
#       |_chunking ->  0.001305 seconds
#       |_chunking ->  0.001211 seconds
#       |_chunking ->  0.001373 seconds
#       |_chunking ->  0.001311 seconds
#       |_chunking ->  0.001248 seconds
#       |_chunking ->  0.001203 seconds
#       |_chunking ->  0.001121 seconds
#       |_chunking ->  0.001201 seconds
#       |_chunking ->  0.001219 seconds
#       |_chunking ->  0.00142 seconds
#       |_chunking ->  0.001378 seconds
#       |_chunking ->  0.001332 seconds
#       |_chunking ->  0.001204 seconds
#       |_chunking ->  0.001037 seconds
#       |_chunking ->  0.001002 seconds
#       |_chunking ->  0.000982 seconds
#       |_chunking ->  0.001112 seconds
#       |_chunking ->  0.001295 seconds
#       |_chunking ->  0.002379 seconds
#       |_chunking ->  0.001153 seconds
#       |_chunking ->  0.00099 seconds
#       |_chunking ->  0.001057 seconds
#       |_chunking ->  0.000955 seconds
#       |_chunking ->  0.000949 seconds
#     |_embedding ->  0.101276 seconds
#     |_embedding ->  0.094528 seconds
#     |_embedding ->  0.075024 seconds
#     |_embedding ->  0.062278 seconds
#     |_embedding ->  0.069882 seconds
#     |_embedding ->  0.066608 seconds
#     |_embedding ->  0.065952 seconds
#     |_embedding ->  0.064764 seconds
#     |_embedding ->  0.066144 seconds
#     |_embedding ->  0.066378 seconds
#     |_embedding ->  0.067112 seconds
#     |_embedding ->  0.067284 seconds
#     |_embedding ->  0.067978 seconds
#     |_embedding ->  0.06118 seconds
#     |_embedding ->  0.066784 seconds
#     |_embedding ->  0.068874 seconds
#     |_embedding ->  0.065374 seconds
#     |_embedding ->  0.068645 seconds
#     |_embedding ->  0.067077 seconds
#     |_embedding ->  0.07564 seconds
#     |_embedding ->  0.075988 seconds
#     |_embedding ->  0.077071 seconds
#     |_embedding ->  0.076086 seconds
#     |_embedding ->  0.076405 seconds
#     |_embedding ->  0.079279 seconds
#     |_embedding ->  0.028225 seconds
# **********
# end_trace

# %%
len(documents)
# Out:
# 253

# %%
from llama_index.prompts.base import Prompt
from llama_index.prompts.prompts import RefinePrompt, QuestionAnswerPrompt
refine_prompt = RefinePrompt(REFINE_PROMPT)
default_prompt = QuestionAnswerPrompt(DEFAULT_PROMPT)

# %%
#query_engine = index.as_query_engine()

'''
retriever = VectorIndexRetriever(
    index=index, 
    similarity_top_k=2,
)
'''

#retriever = index.as_retriever(retriever_mode='embedding',  similarity_top_k=10)
retriever = index.as_retriever(retriever_mode='embedding',  similarity_top_k=20)
#retriever = index.as_retriever(retriever_mode='embedding')

#response_synthesizer = ResponseSynthesizer.from_args(response_mode = ResponseMode.REFINE ,service_context=service_context, text_qa_template=default_prompt, refine_template=refine_prompt, callback_manager=callback_manager, verbose=True)
#response_synthesizer = ResponseSynthesizer.from_args(response_mode = ResponseMode.COMPACT ,service_context=service_context, text_qa_template=default_prompt, refine_template=refine_prompt, callback_manager=callback_manager, verbose=True)
response_synthesizer = ResponseSynthesizer.from_args(response_mode = ResponseMode.SIMPLE_SUMMARIZE ,service_context=service_context, text_qa_template=default_prompt, callback_manager=callback_manager, verbose=True)
query_engine = RetrieverQueryEngine(retriever=retriever, response_synthesizer=response_synthesizer, callback_manager=callback_manager)
'''
query_engine = index.as_query_engine(
    retriever_mode=ListRetrieverMode.EMBEDDING
    , similarity_top_k=3
)
'''

response = query_engine.query(
    "虹夏ちゃんのお姉さんの仕事は？"
)
'''
response = index.query(
    "虹夏ちゃんのお姉さんの仕事は？", 
    mode="embedding", 
    verbose=True, 
    embed_model=embed_model,
    text_qa_template=default_prompt,
    refine_template=refine_prompt,
    similarity_top_k=2
)
'''
response.response
# Out:
# start_trace
# event_type = query (start)
# event_type = retrieve (start)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = retrieve (end)
# NodeWithScore(node=Node(text='へと呼び方を改める。同じ学校のひとりのことを気にかけるが、一方でひとりの性格などを歯に衣着せず述べ、無自覚のうちに精神的ダメージを与えることもしばしば。そのストレートな物言いは虹夏（アニメではリョウ）に「ナチュラルに鬼畜」と評された。両親は共に公務員であり、曰く「母親はしっかりしている」とのこと。 伊地知 星歌（いじち せいか） 声 - 内田真礼 虹夏の姉で、ライブハウス「STARRY」の店長。ク', doc_id='f20c679e-2a65-4dbf-960c-78f3d0546a61', embedding=None, doc_hash='f1fffd144b29d844d5944e7ddbd128d643c1dca420f521ff45122e4c0474b2cf', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '39e96693-416d-40f6-ba53-ee2c61d58b72'}), score=0.6322367996182164)
# NodeWithScore(node=Node(text='とは公にはされていない。 伊地知 虹夏（いじち にじか） 声 - 鈴代紗弓 誕生日：5月29日 / 身長：154cm / 体重：48kg / 血液型：A型 ドラム担当。下北沢高校2年→3年。明るく世話焼きなバンドのリーダーでまとめ役。また、本作におけるツッコミ役。水玉のリボンがトレードマークで、たいてい身体のどこかに身につけている。姉の星歌がライブハウスの店長を務める元バンドマンであることの影響か', doc_id='bfbb1736-cc33-4027-a016-8a74203969ba', embedding=None, doc_hash='0eb4fb3b6342e36092d06b35259bb713812dfee1b1b64a0523b575141981930b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '7fdcf184-c1b2-4744-a576-d7f7ee0eb4c4'}), score=0.6097200924188578)
# NodeWithScore(node=Node(text='ドを始めようと考え、虹夏と喜多に付き合ってもらってギターを購入。以後は学校でもバイト先でも、ひとりにギターを教えてもらおうとまとわりつく。 日向 恵恋奈（ひなた えれな） 作中2年目から登場。16歳で通信制高校在籍の1年生。猫々と同じくSTARRYの新人バイト。一人称は「えれ」。もとは結束バンドと対バンした地下アイドルグループ「天使のキューティクル」のメンバーで、「ラファエル」を名乗っていた。 天', doc_id='878313c6-0a86-4912-81b8-1db5e0ab4552', embedding=None, doc_hash='0e0e17bb17cbb18b55c06f80de896009f8bdffac8efb8497fc68c808426b955f', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd6a99455-cc3a-476e-a21d-c7de4ca88ece'}), score=0.6070670431138556)
# NodeWithScore(node=Node(text='らは「だめな大人」の一人と思われている。 上村 レコーディングエンジニア。朗らかで話し好きな女性。隙あらば料金を上乗せしようとする。 リナ 星歌の元バンドメンバーでドラマー。現在はスタジオミュージシャン。小学生だった虹夏にねだられ、最初にドラムを教えた人物。 星歌に呼ばれ、アルバムレコーディングにてプレッシャーのため実力が出せない虹夏にアドバイスを与えた。 後藤 直樹（ごとう なおき） 声 - 間', doc_id='b3cdc270-d6b0-4e43-9c4c-1e771edf67e5', embedding=None, doc_hash='b9502a944c9f973a52e0012d0242726ad42c7dec4b66412a1c9b66819bfe686e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'ff93cfa3-96eb-46da-b3a4-dae4c6ab27ff'}), score=0.6022962762972365)
# NodeWithScore(node=Node(text='に「ナチュラルに鬼畜」と評された。両親は共に公務員であり、曰く「母親はしっかりしている」とのこと。 伊地知 星歌（いじち せいか） 声 - 内田真礼 虹夏の姉で、ライブハウス「STARRY」の店長。クリスマスイブが誕生日で、初登場時29歳。作中1年目に30歳を迎え、2年目に31歳を迎えた。かつては自身もバンドマン（ギタリスト）で、その実力はレーベルからスカウトの話が来るほどだった。口では虹夏や結束', doc_id='7b708486-f64e-4bf8-90c8-f66548b8f253', embedding=None, doc_hash='004706aa2400cd27e9c921185f53f786fe44e286a7c17327f7d9e5fc514f302d', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '30ef0e4f-4689-45d6-a13d-b6097f397e30'}), score=0.6001406895177273)
# NodeWithScore(node=Node(text='のマネジメント担当となる。 非常に落ち着いた雰囲気の女性だが、初登場時で23歳と若く入社2年目。社会人として冷静に「売ること」を考える一方で、バンドメンバーの考えや方針に対する配慮もしっかり行っている。しっかり者ではあるが、エンジニアが追加料金の話をした時に、シールド持ちながら「この鞭で叩けば少しは早くなりますかね」と発言したり、自宅が非常に汚い為に事務所に寝泊まりしてるような一面もあり、虹夏達か', doc_id='31c0a9b9-7716-446f-b30d-fb12346676a2', embedding=None, doc_hash='aa07bcb2bd2ee8cf915f2549517ab66086c5e49fe2934e9321e04f4502bb0d0e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'fd90ec36-709b-4ed7-a724-bc08d677e3b9'}), score=0.5916819329275937)
# NodeWithScore(node=Node(text='ることになった。 虹夏や郁代によると（普段の奇行のせいで忘れられがちだが）美少女。文化祭でのクラスの出し物でメイド服を着させられた際は皆から似合うと讃えられ、リョウからは「ビジュアル方面で売り出すのもあり」「ダイヤの原石」と評された。タピオカチャレンジ（胸の上へタピオカ飲料のカップを乗せて飲む催し）が可能なほどスタイルも抜群で、虹夏や郁代からは嫉妬混じりの冷たい視線を向けられることもある。郁代によ', doc_id='21f889e7-3ab2-4f34-9c19-47243836d8d0', embedding=None, doc_hash='1ded904ec4c6cb6744ecb7ff1203e3932638e077bd6849f7a5fcebc90f78c0c0', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'b9b9238d-5803-46dd-9ef0-db0a5a96959c'}), score=0.5844234711888077)
# NodeWithScore(node=Node(text='ルト）」の名前でバーチャルYouTuberとして活動しており、ゲーム実況動画などを公開している。具体的な名前については作中で言及されず、主に「PAさん」と呼ばれる。 大山 猫々（おおやま ねね） 作中2年目から登場。16歳で秀華高校1年生。大学受験準備に入って忙しくなった虹夏の代わりとして2年目秋よりSTARRYでアルバイトするようになる。 スポーツ好きで中学時代はバスケ部所属だったこともあり雰囲', doc_id='75fffacf-9f43-47e9-b0c3-b513f706b172', embedding=None, doc_hash='c3af749b0f68694dd07ca0f0383e90cf64d8ea42612c57e66570d0fea6e9b460', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '972959a2-96ba-4e25-a611-605a34bdf73b'}), score=0.5823328043094724)
# NodeWithScore(node=Node(text='メ版の声優。作中の年次の表記はひとりの学年を基準に高校1年時を1年目、進級後を2年目とする。 本作で中心として描かれる下北系ロックバンド。虹夏の姉・星歌が店長を務める下北沢のライブハウス「STARRY（スターリー）」を拠点に活動している。バンド名はリョウによる命名で、ライブの物販では実際に結束バンド（ケーブルタイ）をリストバンドと称して販売している。後にリョウが「けつばんちゃん」というマスコットキ', doc_id='0b2eb920-c255-40f8-8c26-8bed2f9f75bb', embedding=None, doc_hash='fc3fa1fee1485bd4ec4719dc95a54aea756406d9dfd8d9644fc3ea5015f22dce', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3436b94f-ee97-4d00-b71c-784099c5d1ba'}), score=0.5815508275639169)
# NodeWithScore(node=Node(text='NGワードを避けており自ずと暗めの歌詞になる。レーベルミニアルバム制作時には作曲・編曲にも挑戦したものの、編曲の方がうまくいかずリョウにより遠回しに遠ざけられ、結局ひとりが作曲したものをリョウが編曲することになった。 虹夏や郁代によると（普段の奇行のせいで忘れられがちだが）美少女。文化祭でのクラスの出し物でメイド服を着させられた際は皆から似合うと讃えられ、リョウからは「ビジュアル方面で売り出すのも', doc_id='e6ced8d0-1fce-44f9-b254-263b97450eaf', embedding=None, doc_hash='b3ce4ebbdffacd7154007cf8c473b6e3c75044732a6f70979fd49c547805710c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '7d0a1b6c-dccc-419c-bfc6-48538542b944'}), score=0.5700329407411394)
# NodeWithScore(node=Node(text='。しっかり者ではあるが、エンジニアが追加料金の話をした時に、シールド持ちながら「この鞭で叩けば少しは早くなりますかね」と発言したり、自宅が非常に汚い為に事務所に寝泊まりしてるような一面もあり、虹夏達からは「だめな大人」の一人と思われている。 上村 レコーディングエンジニア。朗らかで話し好きな女性。隙あらば料金を上乗せしようとする。 リナ 星歌の元バンドメンバーでドラマー。現在はスタジオミュージシャ', doc_id='36e04dba-ea36-4065-a68f-c31440e6ab52', embedding=None, doc_hash='d400ff223faae6c60fc16251180127dbbfc4151dd053e6927bc4a3e0563cee03', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '37247134-fd8a-4c2e-bda6-5ba67296153c'}), score=0.5653809064803934)
# NodeWithScore(node=Node(text='あり」「ダイヤの原石」と評された。タピオカチャレンジ（胸の上へタピオカ飲料のカップを乗せて飲む催し）が可能なほどスタイルも抜群で、虹夏や郁代からは嫉妬混じりの冷たい視線を向けられることもある。郁代によると、顔を上げ表情も整えればアイドル事務所も狙えるほどのルックスだが、その顔は10秒と持たない。そして自己評価が極めて低く、ひとり自身は外見やスタイルを全く意識していない。 初期設定では普通の可愛い女', doc_id='91d24bbf-b239-44dc-9f96-51f82a2c205d', embedding=None, doc_hash='894f13e695e4c8633351d6725a3276d9cce25f2f64966d9d1d94447e906151ad', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0dbd77d3-7ce9-4733-8310-8dd657c776cc'}), score=0.5639469584980376)
# NodeWithScore(node=Node(text='ギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であることは公にはされていない。 伊地知 虹夏（いじち にじか） 声 - 鈴代紗弓 誕生日：5月29日 / 身長：154cm / 体重：48kg / 血液型：A型 ドラム担当。下北沢高校2年→3年。明るく世話', doc_id='40117faa-524e-435f-864a-65102654c4db', embedding=None, doc_hash='07b488e462ab46c2d27077e81d6dcaa9ad79597f90250cc61695787cdad5ee52', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '9c45a303-fe64-44ce-9a5a-b463f3e215cb'}), score=0.563022890586512)
# NodeWithScore(node=Node(text='終了後、結束バンドを再評価したぽいずん♡やみのツテによって結束バンドにレーベルデビューの話が持ち込まれる。ひとりたちは初のレーベルミニアルバム発売に向け、新曲作りなどへ取り掛かる。 声の項はテレビアニメ版の声優。作中の年次の表記はひとりの学年を基準に高校1年時を1年目、進級後を2年目とする。 本作で中心として描かれる下北系ロックバンド。虹夏の姉・星歌が店長を務める下北沢のライブハウス「STARRY', doc_id='164793e7-88b2-4aa0-a444-5ed04f8c8fea', embedding=None, doc_hash='4caed6d26ea2d6f971532cb6c337a2d53c66f5e336b349856c8f10e40e4080b2', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '54e7cf18-8071-486e-9111-e4b0511bc944'}), score=0.5604444559513851)
# NodeWithScore(node=Node(text='たお金を与えている。 目はいつも何か（髪の毛や、ふたりの手など）に隠されていて描かれていない。 会社では窓際族と説明しているが、自宅は金沢八景（横浜市）の戸建てである。 後藤 美智代（ごとう みちよ） 声 - 末柄里恵 誕生日：4月3日 /血液型：A型 後藤姉妹の母。ひとり及びふたりと同じくピンク色の髪をしている。人見知りなひとりを何かと心配している。喜多が家に来たときは場を盛り上げようと、喜んで', doc_id='eb16fa37-bd06-4085-b536-c76782f7a472', embedding=None, doc_hash='101bde69f35d23537b835d431320a78bbc4c7ccc61be781b86fbde5480615b4a', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '35c14fc4-0284-492d-ac71-c83ab4f8559a'}), score=0.5602419107401008)
# NodeWithScore(node=Node(text='ザがスマートフォンにつけているアクリルチャームは、『スローループ』主人公の海凪ひよりと海凪小春になっている。 イシバシ楽器 原作および、テレビアニメ12話にて御茶ノ水の本店が実名で登場する。また、YouTubeでのテレビアニメ連動企画「ギターヒーローへの道」の第4回にて、ひとり役の青山がギターのケースを買いに行く店として登場する。 [脚注の使い方] ^ 雑誌掲載時の扉や単行本の帯にこの言葉がついて', doc_id='62ff6f0e-c886-422a-afc7-9c8e73509e3b', embedding=None, doc_hash='f54825f0f7cf016dde2a5f90a07dcd5a07a8e296f9dd46aac210ccb2d8c9ed5c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '6c70443a-3b45-4219-bde7-7b962be4c343'}), score=0.5574852035245845)
# NodeWithScore(node=Node(text='ックを受けていた。また、ベースはリョウが買い取った後に転売している。 ^ この出来事はある意味でひとりが虹夏と出会うきっかけを作ることとなり、後に虹夏に謝罪した際に彼女から「喜多ちゃんが逃げてなかったらぼっちちゃんと出会うことはなかった」と逆に感謝された。 ^ 前後してひとりからの呼び方も「喜多さん」から「喜多ちゃん」へと変化している。 ^ ひとりには「目をつけられている」と怯えられている。 ^ ', doc_id='5cba5ff6-14e0-4c7f-ac9c-4f5a1daf0d58', embedding=None, doc_hash='76342cd788a6caee877a0c87975ffd89628f9b8a71e7cc3acb1d4b47da0fc4e5', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'a154d463-d320-4318-ba4f-bd757e747f4b'}), score=0.5568985995604336)
# NodeWithScore(node=Node(text='リスマスイブが誕生日で、初登場時29歳。作中1年目に30歳を迎え、2年目に31歳を迎えた。かつては自身もバンドマン（ギタリスト）で、その実力はレーベルからスカウトの話が来るほどだった。口では虹夏や結束バンドに厳しくあたることもあるが、実際には誰よりも結束バンドのことを親身に考えており、特に虹夏の事で一喜一憂する。ぶっきらぼうな態度や性格に似合わず可愛い物が好きで、ぬいぐるみを抱いていたりメイド服や', doc_id='5b2c9746-0748-43f4-944b-077d2b97e3bb', embedding=None, doc_hash='7a060ccfdcae6ba827e0712df09803a7695d4b5bc001343896396d4d71d18c18', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '8ed9840c-3b9d-4762-82a2-36dcad656839'}), score=0.5568676187252851)
# NodeWithScore(node=Node(text='焼きなバンドのリーダーでまとめ役。また、本作におけるツッコミ役。水玉のリボンがトレードマークで、たいてい身体のどこかに身につけている。姉の星歌がライブハウスの店長を務める元バンドマンであることの影響から、幼い頃からバンド文化に触れてきており、業界事情にも詳しい。小さい頃に母親を亡くし、父親も仕事で家を空けることが多いため、姉を唯一の肉親としている。 バンドを辞めた姉の分まで人気になり、姉のライブハ', doc_id='22f47651-33f9-43bc-a35b-d118c64a2504', embedding=None, doc_hash='fc21da40e9b945c67accfa40dfac268bc3f47247df85d1d5e7671d7e4c6cc8f1', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'ae656777-0cb4-4dd9-9611-ed899a02fcd0'}), score=0.5564467679151597)
# NodeWithScore(node=Node(text='教えていなかったが、ひとりの動画投稿サイトでの活動を収益化する手続きをしており（実在の動画サイトであれば本人が18歳以上であるか法定後見人が必要となる）、ひとりがギターを壊してしまった際に広告収入で得たお金を与えている。 目はいつも何か（髪の毛や、ふたりの手など）に隠されていて描かれていない。 会社では窓際族と説明しているが、自宅は金沢八景（横浜市）の戸建てである。 後藤 美智代（ごとう みちよ）', doc_id='22a597fe-dead-4b92-9e28-6a0601ff0da3', embedding=None, doc_hash='d0353c313aa2e99b2583ff0a9f0f6d4cd09b6dc3ef1f74e51709b3ee8c18e156', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0db841ae-4e5b-45c1-9f0a-a0e29508a688'}), score=0.5562407559483992)
# event_type = synthesize (start)
# event_type = llm (start)
# event_type = llm (end)
# event_type = synthesize (end)
# event_type = query (end)
# **********
# Trace: query
#     |_query ->  1.015316 seconds
#       |_retrieve ->  0.147145 seconds
#         |_embedding ->  0.032096 seconds
#       |_synthesize ->  0.858207 seconds
#         |_llm ->  0.788695 seconds
# **********
# end_trace
# 'リーダー'

# %%
response = query_engine.query(
    "後藤ひとりがギターに熱中するようになった理由になった出来事は？", 
)

response.response
# Out:
# start_trace
# event_type = query (start)
# event_type = retrieve (start)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = retrieve (end)
# NodeWithScore(node=Node(text='ているといち早く気付いている。 先述の性格に加え、運動や勉強など取り柄と言えるものがないというコンプレックスを持っていたところ、中学1年時に暗い学生時代から一転してスターとなったバンドマンのインタビューを目にしたことで、父親の直樹から借りたギターに没頭する。高校入学後はギターを持って公園にいたところを虹夏から声を掛けられ、逃げた郁代の代わりとして臨時で結束バンドのギターを務める運びになり、その流れ', doc_id='73737de5-c21a-4c4b-b299-a670650201fb', embedding=None, doc_hash='149fceaef1e0db6a81f03be82262eee8185340c5c910961eaa382a3ac38104df', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'e959c22d-99ac-4866-b946-e6cc79353d27'}), score=0.7694375794712922)
# NodeWithScore(node=Node(text='島淳司 誕生日：10月16日 / 血液型：O型 後藤姉妹の父。洋楽趣味でギターを所持しており、ひとりは当初そのギターを借りて使用していた。ひとりの音楽活動については「洋楽にハマってほしかった」としながらも好意的に見守っており、文化祭ライブでギターを壊したことを告白された際には「ライブ中に壊すなんて興奮しちゃうなあ」と話すなどロックに対する理解も高いが、当時中1だったひとりに貸し与えたギターは、虹夏', doc_id='43cf34b9-b22a-4702-8362-f0b72ed4b68c', embedding=None, doc_hash='8f8bf3afc81cb8b28e64b95562b838e6fec5d32169301a1ae371679c08f6359c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '5df5ff0c-746f-4452-bdd7-7371cb5353fa'}), score=0.7491898508896726)
# NodeWithScore(node=Node(text='バンドに厳しくあたることもあるが、実際には誰よりも結束バンドのことを親身に考えており、特に虹夏の事で一喜一憂する。ぶっきらぼうな態度や性格に似合わず可愛い物が好きで、ぬいぐるみを抱いていたりメイド服や女子学生服などを鑑賞用に所持していたりする。また涙もろい。 ひとりのギターヒーローとしての正体まではわからなかったものの、ひとりのギタリストとしての才能にもいち早く気づいており、ひとりを中心にした結束', doc_id='3228c475-6f80-4133-b4e4-846a4623cada', embedding=None, doc_hash='4fa744f436248083ef7ea5190d2c7acfaa178b37cf51f5ea34c73540cdedea55', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0dccedae-7001-4093-8c08-5b1639c6fc89'}), score=0.7407938144941589)
# NodeWithScore(node=Node(text='うになった。また、きくりとの出会いや様々なライブを経て、人間的に成長していく。 毎日6時間以上ギターの練習を約3年間欠かさずやってきたため、プロレベルと称されるほど個人としての演奏技術はずば抜けて高い。一方で人前が苦手な性格や、他人と合わせながら演奏する経験の不足からバンド演奏では実力を十分に発揮できず、時折その片鱗を覗かせるに留まっている。結束バンドでは作詞を請け負っているものの、青春に関連した', doc_id='635a14c5-ceef-4435-a31f-ab868f468643', embedding=None, doc_hash='08f903557101ec7c8d9a9a89c28c6a3de8e25e2a0aebcb806eeb698d6db69fdc', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '10bf5a8c-1e71-4cb8-b5bf-51215c868eb5'}), score=0.7384550877776246)
# NodeWithScore(node=Node(text='ーを目にしたことで、父親の直樹から借りたギターに没頭する。高校入学後はギターを持って公園にいたところを虹夏から声を掛けられ、逃げた郁代の代わりとして臨時で結束バンドのギターを務める運びになり、その流れで結束バンドに加入した。その後は改めて加入した郁代とギターの指導による師弟関係を結び、また虹夏やリョウとの交流を経て当初は自分のためとしてやっていた音楽の道を、結束バンドの皆と一緒に進みたいと思えるよ', doc_id='af117566-4038-42f2-a09c-0dfa84fdea7d', embedding=None, doc_hash='d17b1bf67523fdade7a86e1bdf3a6361b232cd538d984b1db5a282e4be646e5c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '16e6da9e-0190-4176-953b-b4da1a294e35'}), score=0.7356226183127347)
# NodeWithScore(node=Node(text='女子学生服などを鑑賞用に所持していたりする。また涙もろい。 ひとりのギターヒーローとしての正体まではわからなかったものの、ひとりのギタリストとしての才能にもいち早く気づいており、ひとりを中心にした結束バンドの動画を密かに撮影するなど注目している。 PAさん 声 - 小岩井ことり ミステリアスな風貌をしたSTARRYの女性PAエンジニア。最終学歴は高校中退。プライベートでは「音戯 アルト（おとぎ ア', doc_id='9624f4f2-e53d-40f5-8e40-9ddaf5118337', embedding=None, doc_hash='407f9383e466c6fb2c2398b375714487f035eb13ab23ab0a795db6783e8afab3', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd93358bc-c320-4999-afa3-ac33bfebfc59'}), score=0.7336249708020189)
# NodeWithScore(node=Node(text='用がある時以外は一切外出せず、実家のライブハウスを手伝うか、家事ばかりをしているなど、インドア派である。さみしがり屋な面もあり、怖い場面に遭遇した際には「お姉ちゃんに会いたい」と泣いたり、ひとりのギターを買いに来た時にはひとりたちが弦楽器に対し、打楽器は自分だけだと孤独感を感じたことがある。また、前のバンドを抜けたリョウを誘い、彼女に改めてバンドの良さを思い出させる、ひとりを結束バンドに誘って彼女', doc_id='856ed6e9-e2ff-43a5-bfb7-77f0238dd7ed', embedding=None, doc_hash='5ed477ceae7d2cc7afe8a8ee1ab9d5ef224116c96a4903822745952dd33f6ce1', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'e40b3cf9-f1de-4879-9a9a-43509d103448'}), score=0.7315461435842316)
# NodeWithScore(node=Node(text='ギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であることは公にはされていない。 伊地知 虹夏（いじち にじか） 声 - 鈴代紗弓 誕生日：5月29日 / 身長：154cm / 体重：48kg / 血液型：A型 ドラム担当。下北沢高校2年→3年。明るく世話', doc_id='40117faa-524e-435f-864a-65102654c4db', embedding=None, doc_hash='07b488e462ab46c2d27077e81d6dcaa9ad79597f90250cc61695787cdad5ee52', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '9c45a303-fe64-44ce-9a5a-b463f3e215cb'}), score=0.7315060892711773)
# NodeWithScore(node=Node(text='スまで結束バンドを取材しに来る。ぽいずん♡やみはそこでのひとりによる演奏のクセを聞いて、ひとりがギターヒーローであることを確信し皆にバラした。ひとり（ギターヒーロー）の腕前なら確実にプロとしても通用すると絶賛した一方、他の結束バンドのメンバーに関しては「”ガチ”じゃない」「本気でプロを目指してやっているようには見えない」と酷評。「ちゃんとしたバンドに入った方がいい」と、ひとりだけを引き抜いて音楽業', doc_id='4ec7deed-c04f-46a7-9079-10b7f2bc84f0', embedding=None, doc_hash='4d124aa7bf2b0930d7d231fe8c026a506fe9c1da144d3a12dffb267ff0b558f6', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '03925c10-c6a6-48d4-aaf9-323f599a0f47'}), score=0.7303379965446709)
# NodeWithScore(node=Node(text='とで改めて結束バンドに加入する。リョウからギターを借り、ひとりの指導の元でギターの練習を重ねた結果、文化祭ライブでは機材トラブルに見舞われたひとりのためにアドリブで時間を繋ぐまでに成長した姿を見せた。レーベルミニアルバム制作時には作詞にも挑戦した。 他人の言動は良い方に解釈しがちで、とくに惚れ込むリョウに対して顕著。当初はひとりのことを「後藤さん」と呼んでいたが、文化祭ライブを機に「ひとりちゃん」', doc_id='bc04a4a5-53fd-40fe-8922-a72bde7064d3', embedding=None, doc_hash='1cfa11ed82830c5802a6f0761bbb3460fb7d43375b3e224aa578234ae0879f6b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '9634d92c-6d78-4aea-85b0-99ddbe376894'}), score=0.7264428617139974)
# NodeWithScore(node=Node(text='た。 そんな中、演奏以上に最後の最後でのひとりのパフォーマンス失敗が話題と化した文化祭ライブのネットに投稿された映像を見て、それを記事にしようと音楽ライターの「ぽいずん♡やみ」こと佐藤愛子がライブハウスまで結束バンドを取材しに来る。ぽいずん♡やみはそこでのひとりによる演奏のクセを聞いて、ひとりがギターヒーローであることを確信し皆にバラした。ひとり（ギターヒーロー）の腕前なら確実にプロとしても通用す', doc_id='48d7fc96-5aaa-47bf-9c97-ffb0075c90c8', embedding=None, doc_hash='a82ae0747711625cfb7c1eed8e63e0f88454f0dbf1487fd42760784c4579774e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '468e50f1-d082-4033-83a6-e135cc68392e'}), score=0.7255692646363785)
# NodeWithScore(node=Node(text='ン。小学生だった虹夏にねだられ、最初にドラムを教えた人物。 星歌に呼ばれ、アルバムレコーディングにてプレッシャーのため実力が出せない虹夏にアドバイスを与えた。 後藤 直樹（ごとう なおき） 声 - 間島淳司 誕生日：10月16日 / 血液型：O型 後藤姉妹の父。洋楽趣味でギターを所持しており、ひとりは当初そのギターを借りて使用していた。ひとりの音楽活動については「洋楽にハマってほしかった」としなが', doc_id='f59adc05-e340-4fee-9d7f-7917d085da5a', embedding=None, doc_hash='0ba93c43574bf655afbea16c7377edfc4482909ce03bc9909cd91b20bc40a456', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '72046f63-bd7e-424e-ae42-8d6ee11c4525'}), score=0.7212789289349917)
# NodeWithScore(node=Node(text='で結束バンドに加入した。その後は改めて加入した郁代とギターの指導による師弟関係を結び、また虹夏やリョウとの交流を経て当初は自分のためとしてやっていた音楽の道を、結束バンドの皆と一緒に進みたいと思えるようになった。また、きくりとの出会いや様々なライブを経て、人間的に成長していく。 毎日6時間以上ギターの練習を約3年間欠かさずやってきたため、プロレベルと称されるほど個人としての演奏技術はずば抜けて高い', doc_id='ab54366f-5423-4788-b457-e939edf7fc30', embedding=None, doc_hash='089d879a9892d62e2b2c1c82254c1a0297c0cd47cb781881c38b2d316c7e76ab', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'cce3e4a2-7afd-469d-b874-85134d4851a5'}), score=0.7205915399974218)
# NodeWithScore(node=Node(text='にも採用されたことがあるが、本人曰く「父さんのバンドはそこがピークでその後は鳴かず飛ばず」のちに妻となる美智代に「就職しなかったら別れる」と言われて辞めたという生々しい経験を語って聞かせた。 本人には教えていなかったが、ひとりの動画投稿サイトでの活動を収益化する手続きをしており（実在の動画サイトであれば本人が18歳以上であるか法定後見人が必要となる）、ひとりがギターを壊してしまった際に広告収入で得', doc_id='ba9604f5-1668-4275-ba93-bd71c3f6bcdd', embedding=None, doc_hash='7384ae1029b65ea689243f9b263fe6949c08c1ffb140d926ead776d88ac07d3e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '05c22381-592d-4767-ad02-32e0cd0529cf'}), score=0.7204204001570246)
# NodeWithScore(node=Node(text='数を取れる（東大合格を目指すと発言したことも）。ただし、必要なくなるとすぐに忘れてしまうほか、勉強に熱中すると音楽関連の知識を忘れてしまう。 元々は、自分に過保護な親に反発していることを示し、親が自分にかまわないようになるのではないかと思ってロックを始めたという経緯があるが、特に親が嫌いというわけではない。 最初期はデザインがかなり異なっている。 喜多 郁代（きた いくよ） 声 - 長谷川育美 誕', doc_id='2109d5c0-7655-48c9-ab19-f5c1d517d208', embedding=None, doc_hash='31c3aef6922c3c34de1ae3922503841ad190343196b92a33f43e365d802d3d80', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'f5b3abc2-0ab7-4864-b000-c2bf83fcabdb'}), score=0.7149369149978124)
# NodeWithScore(node=Node(text='日 / 血液型：B型 音楽情報サイトに寄稿するフリーライター。本名は佐藤 愛子（さとう あいこ）。23歳→24歳。ライターだけで食べていくのは大変なため、「ストレイビート」でアルバイトもしている。 結束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンド', doc_id='fe593f08-dbd4-45c8-a715-1b044a92563a', embedding=None, doc_hash='b77ef4dfb50412ecd1d0d7e9d621cc2f0e2ec66b206cdcaa61422fe259240970', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c1a91ba-a3ba-4b02-8d7a-67c6bd1a527d'}), score=0.714111136022592)
# NodeWithScore(node=Node(text='などを選んでも、バンドメンバーにセンスを酷評されている。 ^ ただし結束バンド加入後はロインで誘われると家から出たり、夏休みはメンバーから遊びに誘われるのを期待して予定を空けておく（実際は入れる予定がそもそもない）など、少しずつではあるが変わりつつある。 ^ プロのギタリストになってテレビでインタビューされた時には何を答えるか考える、逆に人生へ失敗してニートに落ちぶれた自分を想像するなど。 ^ バ', doc_id='5d2fc0b7-d3fd-42c5-9965-c3845b6d769f', embedding=None, doc_hash='17baa4df1f4de185ba404e03a50cfd1e9dfc7b89a10334d2ad8716373622b263', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'c435ac08-f325-4ed3-8d75-3067bf7cd115'}), score=0.7135587578414526)
# NodeWithScore(node=Node(text='束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンドについては「高校生にしたらレベルはまぁ高いと思う」としつつも、その活動姿勢を「ガチじゃない」「本気でプロを目指しているバンドに見えない」と評し「こんなところでうだうだやってると才能腐っちゃいますよ」と', doc_id='d2e4efc2-0308-46ed-8ae8-046216b0add1', embedding=None, doc_hash='b5b68c75508e09c2ab94381ec5596e62cb4040a1e801a35ea12a0811acaecfd6', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '690071fd-aa48-4d24-b452-b215f6c0e307'}), score=0.7125254455001617)
# NodeWithScore(node=Node(text='から撮影された人気バンドのカバー動画を投稿しており、投稿サイトでの登録者数は8万人近く。ぽいずん♡やみのような音楽関係者からも注目を集めている。動画は直樹によって収益化されており、文化祭ライブで壊れたギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であるこ', doc_id='13037695-063d-4cbc-b8c3-ba4bed39c6b3', embedding=None, doc_hash='082aaaaadfca455c46630a2d52c8882237c28f7468c8e83d4c4491a321dee5fe', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c51ddd2-f831-4f9d-a6e9-8bfbf6bc57d5'}), score=0.7122269650874495)
# NodeWithScore(node=Node(text='、SNSでのフォロアー数増減に一喜一憂するなど、実際は小心。その性格を理解している現在のバンドメンバーからは慕われているが、打ち上げに誘われない等ぞんざいに扱われてもいる。 結束バンドのことを知ってわさわざSTARRYに見にいって以後、結束バンドのメンバーとは何かと交流が多くなる。アドバイスを送る、迷子のひとりをSIDEROSメンバーの説得もあってスタジオに誘う、ひとりと動画を合同で撮影する、自動', doc_id='3a6a60c8-796d-4816-bce8-4d89b8ab1893', embedding=None, doc_hash='d06ee4da0e6c221f4d7e9abb36923267da2413e1ec37709a08007eca48b2445c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'ad5615bb-cde4-4b02-a6ee-33bdcb35be9d'}), score=0.7079374586956249)
# event_type = synthesize (start)
# event_type = llm (start)
# event_type = llm (end)
# event_type = synthesize (end)
# event_type = query (end)
# **********
# Trace: query
#     |_query ->  0.959368 seconds
#       |_retrieve ->  0.1077 seconds
#         |_embedding ->  0.027539 seconds
#       |_synthesize ->  0.845722 seconds
#         |_llm ->  0.803868 seconds
# **********
# end_trace
# 'ひとつ'

# %%
response = query_engine.query(
    "ギターヒーローの正体は誰？", 
)
response.response
# Out:
# start_trace
# event_type = query (start)
# event_type = retrieve (start)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = retrieve (end)
# NodeWithScore(node=Node(text='女子学生服などを鑑賞用に所持していたりする。また涙もろい。 ひとりのギターヒーローとしての正体まではわからなかったものの、ひとりのギタリストとしての才能にもいち早く気づいており、ひとりを中心にした結束バンドの動画を密かに撮影するなど注目している。 PAさん 声 - 小岩井ことり ミステリアスな風貌をしたSTARRYの女性PAエンジニア。最終学歴は高校中退。プライベートでは「音戯 アルト（おとぎ ア', doc_id='9624f4f2-e53d-40f5-8e40-9ddaf5118337', embedding=None, doc_hash='407f9383e466c6fb2c2398b375714487f035eb13ab23ab0a795db6783e8afab3', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd93358bc-c320-4999-afa3-ac33bfebfc59'}), score=0.6518938883814517)
# NodeWithScore(node=Node(text='束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンドについては「高校生にしたらレベルはまぁ高いと思う」としつつも、その活動姿勢を「ガチじゃない」「本気でプロを目指しているバンドに見えない」と評し「こんなところでうだうだやってると才能腐っちゃいますよ」と', doc_id='d2e4efc2-0308-46ed-8ae8-046216b0add1', embedding=None, doc_hash='b5b68c75508e09c2ab94381ec5596e62cb4040a1e801a35ea12a0811acaecfd6', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '690071fd-aa48-4d24-b452-b215f6c0e307'}), score=0.6437134989097185)
# NodeWithScore(node=Node(text='の子だったが、担当編集から「もっとガチにした方がいい」と指摘を受けて修正していき、たちまち現在の設定となった。 ギターヒーロー ひとりが動画投稿サイトで活動する際に用いるハンドルネーム。ひとりが普段人前に出せないが内面に抱えている承認欲求の象徴とも言えるもので、現実のひとりからはかけ離れた「バスケ部エースの彼氏持ち」や「ラインの友達数は1000人超え」といった設定がつけられている。顔を隠すアングル', doc_id='e3d4ac9f-ffc8-4b69-a46a-c5b8745273bd', embedding=None, doc_hash='4ad06326b3a986a3f99560bcd630c1d0406a4606d3c849bae1ea563d009ef828', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '548410ee-d205-4482-986a-8ddb3678942a'}), score=0.6270248911326346)
# NodeWithScore(node=Node(text='スまで結束バンドを取材しに来る。ぽいずん♡やみはそこでのひとりによる演奏のクセを聞いて、ひとりがギターヒーローであることを確信し皆にバラした。ひとり（ギターヒーロー）の腕前なら確実にプロとしても通用すると絶賛した一方、他の結束バンドのメンバーに関しては「”ガチ”じゃない」「本気でプロを目指してやっているようには見えない」と酷評。「ちゃんとしたバンドに入った方がいい」と、ひとりだけを引き抜いて音楽業', doc_id='4ec7deed-c04f-46a7-9079-10b7f2bc84f0', embedding=None, doc_hash='4d124aa7bf2b0930d7d231fe8c026a506fe9c1da144d3a12dffb267ff0b558f6', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '03925c10-c6a6-48d4-aaf9-323f599a0f47'}), score=0.620040983910424)
# NodeWithScore(node=Node(text='バンドに厳しくあたることもあるが、実際には誰よりも結束バンドのことを親身に考えており、特に虹夏の事で一喜一憂する。ぶっきらぼうな態度や性格に似合わず可愛い物が好きで、ぬいぐるみを抱いていたりメイド服や女子学生服などを鑑賞用に所持していたりする。また涙もろい。 ひとりのギターヒーローとしての正体まではわからなかったものの、ひとりのギタリストとしての才能にもいち早く気づいており、ひとりを中心にした結束', doc_id='3228c475-6f80-4133-b4e4-846a4623cada', embedding=None, doc_hash='4fa744f436248083ef7ea5190d2c7acfaa178b37cf51f5ea34c73540cdedea55', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0dccedae-7001-4093-8c08-5b1639c6fc89'}), score=0.6199549634551246)
# NodeWithScore(node=Node(text='日 / 血液型：B型 音楽情報サイトに寄稿するフリーライター。本名は佐藤 愛子（さとう あいこ）。23歳→24歳。ライターだけで食べていくのは大変なため、「ストレイビート」でアルバイトもしている。 結束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンド', doc_id='fe593f08-dbd4-45c8-a715-1b044a92563a', embedding=None, doc_hash='b77ef4dfb50412ecd1d0d7e9d621cc2f0e2ec66b206cdcaa61422fe259240970', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c1a91ba-a3ba-4b02-8d7a-67c6bd1a527d'}), score=0.6153186586583052)
# NodeWithScore(node=Node(text='ギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であることは公にはされていない。 伊地知 虹夏（いじち にじか） 声 - 鈴代紗弓 誕生日：5月29日 / 身長：154cm / 体重：48kg / 血液型：A型 ドラム担当。下北沢高校2年→3年。明るく世話', doc_id='40117faa-524e-435f-864a-65102654c4db', embedding=None, doc_hash='07b488e462ab46c2d27077e81d6dcaa9ad79597f90250cc61695787cdad5ee52', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '9c45a303-fe64-44ce-9a5a-b463f3e215cb'}), score=0.6133642047336854)
# NodeWithScore(node=Node(text='いい」。 イシバシ楽器 ひとりがギターを入手する際に利用した御茶ノ水の楽器店。御茶ノ水、渋谷、新宿等に店舗がある同名の楽器チェーン店をモデルにしており、作中ではSTARRYを開く以前の星歌が働いていた設定となっている。 アニメに連動してYouTubeにて公開された番組「ギターヒーローへの道」では、ひとり役の青山がギターケースなどを購入するためにモデルとなった店舗を訪れている。 未確認ライオット ぽ', doc_id='3e4f5017-47f8-453c-86fe-8047c171f1b0', embedding=None, doc_hash='1663a4d7ec70896ec1b99060249f504a4f60094fb2120e94ece3ce08ebca8261', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '499dfe12-a456-434e-b6ee-75f90d7fb4c9'}), score=0.6005198890023122)
# NodeWithScore(node=Node(text='から撮影された人気バンドのカバー動画を投稿しており、投稿サイトでの登録者数は8万人近く。ぽいずん♡やみのような音楽関係者からも注目を集めている。動画は直樹によって収益化されており、文化祭ライブで壊れたギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であるこ', doc_id='13037695-063d-4cbc-b8c3-ba4bed39c6b3', embedding=None, doc_hash='082aaaaadfca455c46630a2d52c8882237c28f7468c8e83d4c4491a321dee5fe', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c51ddd2-f831-4f9d-a6e9-8bfbf6bc57d5'}), score=0.5994641018363325)
# NodeWithScore(node=Node(text='設定となっている。 アニメに連動してYouTubeにて公開された番組「ギターヒーローへの道」では、ひとり役の青山がギターケースなどを購入するためにモデルとなった店舗を訪れている。 未確認ライオット ぽいずん♡やみから活動姿勢を否定された結束バンドが実力を証明するためにエントリーを決めた10代アーティスト限定のロックフェス。デモ審査、ウェブ投票、ライブ審査を経て最終審査がフェス形式で行われる。優勝賞', doc_id='c226e698-a42a-4bf1-8fb3-01043f6ec90d', embedding=None, doc_hash='4623d17e9e46ebdbd6957cee8caa4a875290a8acface0d37f9ffdb499e483087', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '8de3e4e2-a920-4059-a740-a64de731e87e'}), score=0.59675329451729)
# NodeWithScore(node=Node(text='た。 そんな中、演奏以上に最後の最後でのひとりのパフォーマンス失敗が話題と化した文化祭ライブのネットに投稿された映像を見て、それを記事にしようと音楽ライターの「ぽいずん♡やみ」こと佐藤愛子がライブハウスまで結束バンドを取材しに来る。ぽいずん♡やみはそこでのひとりによる演奏のクセを聞いて、ひとりがギターヒーローであることを確信し皆にバラした。ひとり（ギターヒーロー）の腕前なら確実にプロとしても通用す', doc_id='48d7fc96-5aaa-47bf-9c97-ffb0075c90c8', embedding=None, doc_hash='a82ae0747711625cfb7c1eed8e63e0f88454f0dbf1487fd42760784c4579774e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '468e50f1-d082-4033-83a6-e135cc68392e'}), score=0.5869590193902586)
# NodeWithScore(node=Node(text='ザがスマートフォンにつけているアクリルチャームは、『スローループ』主人公の海凪ひよりと海凪小春になっている。 イシバシ楽器 原作および、テレビアニメ12話にて御茶ノ水の本店が実名で登場する。また、YouTubeでのテレビアニメ連動企画「ギターヒーローへの道」の第4回にて、ひとり役の青山がギターのケースを買いに行く店として登場する。 [脚注の使い方] ^ 雑誌掲載時の扉や単行本の帯にこの言葉がついて', doc_id='62ff6f0e-c886-422a-afc7-9c8e73509e3b', embedding=None, doc_hash='f54825f0f7cf016dde2a5f90a07dcd5a07a8e296f9dd46aac210ccb2d8c9ed5c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '6c70443a-3b45-4219-bde7-7b962be4c343'}), score=0.5796200299589581)
# NodeWithScore(node=Node(text='ているといち早く気付いている。 先述の性格に加え、運動や勉強など取り柄と言えるものがないというコンプレックスを持っていたところ、中学1年時に暗い学生時代から一転してスターとなったバンドマンのインタビューを目にしたことで、父親の直樹から借りたギターに没頭する。高校入学後はギターを持って公園にいたところを虹夏から声を掛けられ、逃げた郁代の代わりとして臨時で結束バンドのギターを務める運びになり、その流れ', doc_id='73737de5-c21a-4c4b-b299-a670650201fb', embedding=None, doc_hash='149fceaef1e0db6a81f03be82262eee8185340c5c910961eaa382a3ac38104df', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'e959c22d-99ac-4866-b946-e6cc79353d27'}), score=0.5781900510897899)
# NodeWithScore(node=Node(text='ると、顔を上げ表情も整えればアイドル事務所も狙えるほどのルックスだが、その顔は10秒と持たない。そして自己評価が極めて低く、ひとり自身は外見やスタイルを全く意識していない。 初期設定では普通の可愛い女の子だったが、担当編集から「もっとガチにした方がいい」と指摘を受けて修正していき、たちまち現在の設定となった。 ギターヒーロー ひとりが動画投稿サイトで活動する際に用いるハンドルネーム。ひとりが普段人', doc_id='4e021163-6558-4120-88f7-1d564db1a7d5', embedding=None, doc_hash='510bb7d048c9ae25a3abc9351bbd8f2a9c5c0800244c43663007fe1b280b68f2', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd16b696b-fdf7-41bb-bff7-f4ce9151115e'}), score=0.5749474811285522)
# NodeWithScore(node=Node(text='uTubeでのテレビアニメ連動企画「ギターヒーローへの道」の第4回にて、ひとり役の青山がギターのケースを買いに行く店として登場する。 [脚注の使い方] ^ 雑誌掲載時の扉や単行本の帯にこの言葉がついていることが多く、アニメの公式Twitterなどでもよく使われている。 ^ 観客に受け止めてもらうつもりで檀上からダイブしたが、皆に避けられそのまま床に落下・激突した。 ^ ネットに流れていた映像はひと', doc_id='1e973d6f-12fa-4691-b3ef-ae99fa21172a', embedding=None, doc_hash='07a15fa8991cd4cfad328a6bcc3e446dc5a59bf09ccb1769845671ddee68a02b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'e12a1d71-9f44-47ec-9dcd-0a7d4cce06e3'}), score=0.5697179318470039)
# NodeWithScore(node=Node(text='ステージ衣装は全て彼女の手作りである。ルシファーとベルフェゴールちゃんという人形の友達がいる。 ケモノリア 結束バンドと同年代のメンバーで構成されたエレクトロロックバンド。芸大生のボーカルが所属し、都内を中心に活動している。未確認ライオットではライブ審査で結束バンド、SIDEROSと同グループとなる。未確認ライオット時、ボーカルとドラムが一発芸の事で喧嘩となる。 なんばガールズ 結束バンドと同年代', doc_id='b64429b0-4211-428c-ae76-24bb4c5025e3', embedding=None, doc_hash='ba7f5b7c1bde25af95f788ae1eca4844ace14754b98ce23c1385a516781f932e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '5fa1b1c3-edb7-4d0d-a05c-790ac8f31919'}), score=0.5686225519502699)
# NodeWithScore(node=Node(text='バンドの動画を密かに撮影するなど注目している。 PAさん 声 - 小岩井ことり ミステリアスな風貌をしたSTARRYの女性PAエンジニア。最終学歴は高校中退。プライベートでは「音戯 アルト（おとぎ アルト）」の名前でバーチャルYouTuberとして活動しており、ゲーム実況動画などを公開している。具体的な名前については作中で言及されず、主に「PAさん」と呼ばれる。 大山 猫々（おおやま ねね） 作中', doc_id='cabd382e-ac7d-4b1d-9095-2a5f8c3ed208', embedding=None, doc_hash='8080d22e74831e52c18585c301e68394b40e20558d665281100595cc9f520b56', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'c60fce83-468b-4d2b-8d61-86b1fa1de1ba'}), score=0.5639619181376059)
# NodeWithScore(node=Node(text='え、他のメンバーを俯瞰するように眺めて、口に出さずとも心の中でツッコミを入れていることも多い。興奮すると口調が汚くなるという一面もある。 元々ギターヒーローのファンであり、その正体がひとりであることに最も早く気づいたが、ひとりの希望もあり、ぽいずん♡やみによって正体を明かされるまでは他メンバーにはこのことを黙っていた。 山田 リョウ（やまだ リョウ） 声 - 水野朔 誕生日：9月18日 / 身長：', doc_id='66d7ad48-9050-483d-9647-2bf78fc68b7d', embedding=None, doc_hash='4d9945e3f2bc839476c75f55212abf3cd7c1102d4c3738c26bd1f3efc554fb3d', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '8d1eec91-1df0-41eb-a937-b92ecce3f45d'}), score=0.5616899618491781)
# NodeWithScore(node=Node(text='島淳司 誕生日：10月16日 / 血液型：O型 後藤姉妹の父。洋楽趣味でギターを所持しており、ひとりは当初そのギターを借りて使用していた。ひとりの音楽活動については「洋楽にハマってほしかった」としながらも好意的に見守っており、文化祭ライブでギターを壊したことを告白された際には「ライブ中に壊すなんて興奮しちゃうなあ」と話すなどロックに対する理解も高いが、当時中1だったひとりに貸し与えたギターは、虹夏', doc_id='43cf34b9-b22a-4702-8362-f0b72ed4b68c', embedding=None, doc_hash='8f8bf3afc81cb8b28e64b95562b838e6fec5d32169301a1ae371679c08f6359c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '5df5ff0c-746f-4452-bdd7-7371cb5353fa'}), score=0.5610544400901593)
# NodeWithScore(node=Node(text='ンバーで構成されたメタルバンド。読みは「シデロス」。SICK HACKと同じくFOLTを拠点に活動しており、既にワンマンライブを行えるだけの人気を集めている。結成自体は3年前であるものの、リーダーであるヨヨコの人付き合いに難があるためメンバーの入れ替わりが激しく、現在のメンバーでは1年目。 大槻 ヨヨコ（おおつき ヨヨコ） 誕生日：6月2日 / 血液型：A型 ギター、ボーカル担当。作中2年目時点で', doc_id='3c540f16-6e38-49e1-92a1-54348a8309c5', embedding=None, doc_hash='3c6a01b6ff23769361f9e2a7bcc49263457c12e84124dd465bc76da89389a209', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'bbb50dad-3ca2-425e-984f-70c3e131aed3'}), score=0.5574588054582367)
# event_type = synthesize (start)
# event_type = llm (start)
# event_type = llm (end)
# event_type = synthesize (end)
# event_type = query (end)
# **********
# Trace: query
#     |_query ->  0.842849 seconds
#       |_retrieve ->  0.092578 seconds
#         |_embedding ->  0.021712 seconds
#       |_synthesize ->  0.745175 seconds
#         |_llm ->  0.714306 seconds
# **********
# end_trace
# 'ひとり'

# %%
response = query_engine.query(
    "喜多郁代の両親の仕事は？", 
)
response.response
# Out:
# start_trace
# event_type = query (start)
# event_type = retrieve (start)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = retrieve (end)
# NodeWithScore(node=Node(text=' 声 - 末柄里恵 誕生日：4月3日 /血液型：A型 後藤姉妹の母。ひとり及びふたりと同じくピンク色の髪をしている。人見知りなひとりを何かと心配している。喜多が家に来たときは場を盛り上げようと、喜んで学生コスプレまでした（21年ぶりに制服を着たとのこと）。結束バンドを夫と一緒になって応援しており、そのためにも学生に扮したことがある。 後藤 ふたり（ごとう ふたり） 声 - 和多田美咲 誕生日：7月', doc_id='08b4e7b5-73e7-42a7-ad32-474b0e5d25c3', embedding=None, doc_hash='13f8ed649c5bd8da206e9c2fee94596210a60d1b1bc43d80ddd53dd224a680d4', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '01a0b402-a430-4c8d-9281-be432f618b30'}), score=0.6503665888554039)
# NodeWithScore(node=Node(text='たお金を与えている。 目はいつも何か（髪の毛や、ふたりの手など）に隠されていて描かれていない。 会社では窓際族と説明しているが、自宅は金沢八景（横浜市）の戸建てである。 後藤 美智代（ごとう みちよ） 声 - 末柄里恵 誕生日：4月3日 /血液型：A型 後藤姉妹の母。ひとり及びふたりと同じくピンク色の髪をしている。人見知りなひとりを何かと心配している。喜多が家に来たときは場を盛り上げようと、喜んで', doc_id='eb16fa37-bd06-4085-b536-c76782f7a472', embedding=None, doc_hash='101bde69f35d23537b835d431320a78bbc4c7ccc61be781b86fbde5480615b4a', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '35c14fc4-0284-492d-ac71-c83ab4f8559a'}), score=0.6231811242712748)
# NodeWithScore(node=Node(text=' 小岩井ことり 後藤家で飼われている犬。直樹によって洋楽由来で名付けられた。初対面の相手にもよくなつく。 リョウの両親 職業は病院の経営。リョウを溺愛しているが、本人からはその愛情を疎ましがられてもいる。だが、バンドのために車を出してもらうなど、リョウは時々頼ってもいる。 結束バンドのファン1号・2号 声 - 市ノ瀬加那（1号）、島袋美由利（2号） ひとりときくりの即興ライブを見て結束バンドのライ', doc_id='36d5dd3a-08db-4cea-b1fb-485a927e40af', embedding=None, doc_hash='29aab1398db829a79a15bcf18981505ec3a904772f1ab7cf5d7f68dca8d0181b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '1e58a5dd-b12b-4042-b0ba-fecf444957e7'}), score=0.592077589224904)
# NodeWithScore(node=Node(text='ン。小学生だった虹夏にねだられ、最初にドラムを教えた人物。 星歌に呼ばれ、アルバムレコーディングにてプレッシャーのため実力が出せない虹夏にアドバイスを与えた。 後藤 直樹（ごとう なおき） 声 - 間島淳司 誕生日：10月16日 / 血液型：O型 後藤姉妹の父。洋楽趣味でギターを所持しており、ひとりは当初そのギターを借りて使用していた。ひとりの音楽活動については「洋楽にハマってほしかった」としなが', doc_id='f59adc05-e340-4fee-9d7f-7917d085da5a', embedding=None, doc_hash='0ba93c43574bf655afbea16c7377edfc4482909ce03bc9909cd91b20bc40a456', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '72046f63-bd7e-424e-ae42-8d6ee11c4525'}), score=0.5862011297896885)
# NodeWithScore(node=Node(text='には虹夏の依頼で撮影にも協力している。具体的な名前については作中で言及されず、2人のうちロングヘアの女性が「1号さん」、ミディアムヘアの女性が「2号さん」と呼ばれる。 佐々木 次子（ささき つぐこ） 誕生日：4月2日 / 血液型：O型 作中2年目から登場する、ひとりと喜多のクラスメイト。喜多とは中学から5年連続同じクラスの腐れ縁で、「さっつー」のニックネームで呼ばれる。また、ひとりからは「ささささ', doc_id='c02285ef-1048-47de-b999-55b1700cb1ff', embedding=None, doc_hash='468278834e663aea8b39c1fb62a1a0474c9e9424909acad483adaa247ca13a5a', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3f4d5cb2-b8ae-42b4-b380-01b7664cba24'}), score=0.580178180976608)
# NodeWithScore(node=Node(text='島淳司 誕生日：10月16日 / 血液型：O型 後藤姉妹の父。洋楽趣味でギターを所持しており、ひとりは当初そのギターを借りて使用していた。ひとりの音楽活動については「洋楽にハマってほしかった」としながらも好意的に見守っており、文化祭ライブでギターを壊したことを告白された際には「ライブ中に壊すなんて興奮しちゃうなあ」と話すなどロックに対する理解も高いが、当時中1だったひとりに貸し与えたギターは、虹夏', doc_id='43cf34b9-b22a-4702-8362-f0b72ed4b68c', embedding=None, doc_hash='8f8bf3afc81cb8b28e64b95562b838e6fec5d32169301a1ae371679c08f6359c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '5df5ff0c-746f-4452-bdd7-7371cb5353fa'}), score=0.566658061559569)
# NodeWithScore(node=Node(text='学生コスプレまでした（21年ぶりに制服を着たとのこと）。結束バンドを夫と一緒になって応援しており、そのためにも学生に扮したことがある。 後藤 ふたり（ごとう ふたり） 声 - 和多田美咲 誕生日：7月7日 /血液型：A型 ひとりの妹。5歳。性格は姉とは正反対で初対面の相手にも物怖じしない。無邪気に相手の心を抉るようなことを言って、（特にひとりに）精神的ダメージを与えることが多い。 ジミヘン 声 -', doc_id='43fd228b-1228-4ae1-8aa0-8dc5db87cb39', embedding=None, doc_hash='d15abda060657c96dca31c56151af2b8a6199c207d2df46aa58718ed06a1e465', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '8ff6265f-59f6-4f12-b5a2-559c1096850e'}), score=0.5596021472495804)
# NodeWithScore(node=Node(text='数を取れる（東大合格を目指すと発言したことも）。ただし、必要なくなるとすぐに忘れてしまうほか、勉強に熱中すると音楽関連の知識を忘れてしまう。 元々は、自分に過保護な親に反発していることを示し、親が自分にかまわないようになるのではないかと思ってロックを始めたという経緯があるが、特に親が嫌いというわけではない。 最初期はデザインがかなり異なっている。 喜多 郁代（きた いくよ） 声 - 長谷川育美 誕', doc_id='2109d5c0-7655-48c9-ab19-f5c1d517d208', embedding=None, doc_hash='31c3aef6922c3c34de1ae3922503841ad190343196b92a33f43e365d802d3d80', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'f5b3abc2-0ab7-4864-b000-c2bf83fcabdb'}), score=0.5546793854305541)
# NodeWithScore(node=Node(text='と喜多が猫々と訪れた渋谷の楽器店で50万円で販売されていた製品の同型であり、妻や次女のふたりもふくめて家族に非常に甘い人物である。 自分自身、学生時代にはバンドをしていて作曲の経験もあり、ローカルCMにも採用されたことがあるが、本人曰く「父さんのバンドはそこがピークでその後は鳴かず飛ばず」のちに妻となる美智代に「就職しなかったら別れる」と言われて辞めたという生々しい経験を語って聞かせた。 本人には', doc_id='af5202ae-23f8-468a-9eec-06d7f84a1f4e', embedding=None, doc_hash='b424f6e25b534e190d2d9cb0c9049244ddb074de1e7c683922a9272e5a3fd710', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'def52338-0067-4ef8-8517-134d28dc0c59'}), score=0.5381277590870079)
# NodeWithScore(node=Node(text='へと呼び方を改める。同じ学校のひとりのことを気にかけるが、一方でひとりの性格などを歯に衣着せず述べ、無自覚のうちに精神的ダメージを与えることもしばしば。そのストレートな物言いは虹夏（アニメではリョウ）に「ナチュラルに鬼畜」と評された。両親は共に公務員であり、曰く「母親はしっかりしている」とのこと。 伊地知 星歌（いじち せいか） 声 - 内田真礼 虹夏の姉で、ライブハウス「STARRY」の店長。ク', doc_id='f20c679e-2a65-4dbf-960c-78f3d0546a61', embedding=None, doc_hash='f1fffd144b29d844d5944e7ddbd128d643c1dca420f521ff45122e4c0474b2cf', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '39e96693-416d-40f6-ba53-ee2c61d58b72'}), score=0.5371701010983998)
# NodeWithScore(node=Node(text='22年12月7日閲覧。 ^ 梅原翔太 [@kafunsyokougun] (2022年12月24日). "ぼっち・ざ・ろっく！のアニメと原作の最大の架け橋は原作の担当編集の瀬古口拓也さんです。はまじさんと信頼し合ってる様子やメールの返事の速度と的確さに、仕事ができる人がこのプロジェクトの中心にいて安心〜！てなりました。アフレコは監督と瀬古口さんが特に楽しそうに笑ってました" (ツイート). Twi', doc_id='0096d137-70bf-4e25-8310-0a412df613c3', embedding=None, doc_hash='84241466dd57e57c316dfe74024cb4734a5597a685b608f2e4ea0cf3bd408683', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd8548086-ce6c-41d0-8f87-ffe499f2e338'}), score=0.5339101892252351)
# NodeWithScore(node=Node(text='教えていなかったが、ひとりの動画投稿サイトでの活動を収益化する手続きをしており（実在の動画サイトであれば本人が18歳以上であるか法定後見人が必要となる）、ひとりがギターを壊してしまった際に広告収入で得たお金を与えている。 目はいつも何か（髪の毛や、ふたりの手など）に隠されていて描かれていない。 会社では窓際族と説明しているが、自宅は金沢八景（横浜市）の戸建てである。 後藤 美智代（ごとう みちよ）', doc_id='22a597fe-dead-4b92-9e28-6a0601ff0da3', embedding=None, doc_hash='d0353c313aa2e99b2583ff0a9f0f6d4cd09b6dc3ef1f74e51709b3ee8c18e156', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0db841ae-4e5b-45c1-9f0a-a0e29508a688'}), score=0.5307939438418006)
# NodeWithScore(node=Node(text='にかまわないようになるのではないかと思ってロックを始めたという経緯があるが、特に親が嫌いというわけではない。 最初期はデザインがかなり異なっている。 喜多 郁代（きた いくよ） 声 - 長谷川育美 誕生日：4月21日 / 身長：158cm / 体重：44kg / 血液型：A型 ギター、ボーカル担当。秀華高校1年→2年。「人と関わるのが大好き」と自称するように社交的で友達も多い、いわゆる「陽キャ」。', doc_id='caf2fce1-6a4b-454d-a33b-cf3a285b8e19', embedding=None, doc_hash='e796f2c353476fc308d691afd5f61c274012d8e627365afbc1cf6bcc2606d31f', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'ccf6c6a7-b77f-4190-9c1e-3268bd0acaef'}), score=0.5253723075646609)
# NodeWithScore(node=Node(text='19日→山田リョウの9月18日、喜多建介の1月24日→喜多郁代の4月21日。 ^ 本人は他人から初めて名付けてもらったあだ名と喜び、気に入っている。この名を付けられたきっかけは、ライブでのメンバー紹介時に本名を出してほしくないと希望したため。以前は虹夏から「ひとりちゃん」、リョウから「ひとり」と呼ばれていた。きくりもニックネームを知るまでは「ひとりちゃん」と呼んでいた。 ^ テレビ番組『69号室の', doc_id='c8b3b981-9c3b-4775-be8e-8fcf98ab2f2d', embedding=None, doc_hash='ca687f5ad93f5ce1c84a3d7a84f714053d24120834dc32fd5b7d59a236ee96c1', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'f0dc2201-47ba-4aa5-b63d-49b91f738fb4'}), score=0.524734419191908)
# NodeWithScore(node=Node(text='らも好意的に見守っており、文化祭ライブでギターを壊したことを告白された際には「ライブ中に壊すなんて興奮しちゃうなあ」と話すなどロックに対する理解も高いが、当時中1だったひとりに貸し与えたギターは、虹夏と喜多が猫々と訪れた渋谷の楽器店で50万円で販売されていた製品の同型であり、妻や次女のふたりもふくめて家族に非常に甘い人物である。 自分自身、学生時代にはバンドをしていて作曲の経験もあり、ローカルCM', doc_id='4395bad8-6a4e-4108-9572-9151d14dda97', embedding=None, doc_hash='5f66deb8a47c4a752a399f4dea5354f949345d186757799b69b9bcfab898a3ee', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '70913780-e9a7-4d5c-ae09-8fa6dca9bfe8'}), score=0.5243475354326209)
# NodeWithScore(node=Node(text='は虹夏の希望（未定）で彼女は作詞作曲には関わっていないため、実際のジャンルは不明である。 ^ 後藤正文の12月2日→後藤ひとりの2月21日、伊地知潔の9月25日→伊地知虹夏の5月29日、山田貴洋の8月19日→山田リョウの9月18日、喜多建介の1月24日→喜多郁代の4月21日。 ^ 本人は他人から初めて名付けてもらったあだ名と喜び、気に入っている。この名を付けられたきっかけは、ライブでのメンバー紹介', doc_id='a6583cd2-1e3e-4d86-95ab-b7b6515966eb', embedding=None, doc_hash='94102736536108bb2f94892f07f32cc8d2bc7e11ad43bb55aa69dc8d95ecea43', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'cb0ed5a0-2db0-4ca2-abb8-a2b6d9ac7f19'}), score=0.5228795239207255)
# NodeWithScore(node=Node(text='ックを受けていた。また、ベースはリョウが買い取った後に転売している。 ^ この出来事はある意味でひとりが虹夏と出会うきっかけを作ることとなり、後に虹夏に謝罪した際に彼女から「喜多ちゃんが逃げてなかったらぼっちちゃんと出会うことはなかった」と逆に感謝された。 ^ 前後してひとりからの呼び方も「喜多さん」から「喜多ちゃん」へと変化している。 ^ ひとりには「目をつけられている」と怯えられている。 ^ ', doc_id='5cba5ff6-14e0-4c7f-ac9c-4f5a1daf0d58', embedding=None, doc_hash='76342cd788a6caee877a0c87975ffd89628f9b8a71e7cc3acb1d4b47da0fc4e5', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'a154d463-d320-4318-ba4f-bd757e747f4b'}), score=0.5221032860745423)
# NodeWithScore(node=Node(text='が変わるきっかけを作る、一度は逃げた郁代を心配していた上に結束バンドに改めて誘う際も戻るよう促し、あっさり迎え入れるなど、リーダーシップが高い。 ライブハウスの上階にある自宅では、同居する姉の分も含めて料理などの家事を行う。学業も人並み以上にこなし、芳大への進学を希望している。 親友で同じクラスであるリョウの面倒を見ることが身に染みついてしまっているが、リョウに対しては殴ったり、プロレス技をかけた', doc_id='d26707b4-3fb7-4156-ab51-a73e3510a46a', embedding=None, doc_hash='f51246fce3221f970559ddcbab37e024e8ab5530b23a69caceb9de1392aa4671', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '9cdac17e-9e36-4c3c-a471-6f31c8054781'}), score=0.5191100051479699)
# NodeWithScore(node=Node(text='ブチケットを購入した2人組の女性ファン。ライブ当日は台風の中STARRYまで足を運び、以降も度々結束バンドのライブを訪れるようになる。普段は美術大学の映像学科で学ぶ学生で、結束バンドがMVを制作する際には虹夏の依頼で撮影にも協力している。具体的な名前については作中で言及されず、2人のうちロングヘアの女性が「1号さん」、ミディアムヘアの女性が「2号さん」と呼ばれる。 佐々木 次子（ささき つぐこ） ', doc_id='77e13700-d59c-4848-93d3-f1b69f18a1d7', embedding=None, doc_hash='3b66e5a199b697c86f019fea588cc1b6e3901f2e7e2de97b578c564d173871c3', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '81457593-98e9-4c2d-9dee-e6cdb4c399bc'}), score=0.5181421391228962)
# NodeWithScore(node=Node(text='に「ナチュラルに鬼畜」と評された。両親は共に公務員であり、曰く「母親はしっかりしている」とのこと。 伊地知 星歌（いじち せいか） 声 - 内田真礼 虹夏の姉で、ライブハウス「STARRY」の店長。クリスマスイブが誕生日で、初登場時29歳。作中1年目に30歳を迎え、2年目に31歳を迎えた。かつては自身もバンドマン（ギタリスト）で、その実力はレーベルからスカウトの話が来るほどだった。口では虹夏や結束', doc_id='7b708486-f64e-4bf8-90c8-f66548b8f253', embedding=None, doc_hash='004706aa2400cd27e9c921185f53f786fe44e286a7c17327f7d9e5fc514f302d', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '30ef0e4f-4689-45d6-a13d-b6097f397e30'}), score=0.5172770066388258)
# event_type = synthesize (start)
# event_type = llm (start)
# event_type = llm (end)
# event_type = synthesize (end)
# event_type = query (end)
# **********
# Trace: query
#     |_query ->  0.854847 seconds
#       |_retrieve ->  0.089388 seconds
#         |_embedding ->  0.024728 seconds
#       |_synthesize ->  0.758979 seconds
#         |_llm ->  0.737425 seconds
# **********
# end_trace
# '公務員'

# %%
response = query_engine.query(
    "ひとりが動画投稿する時のハンドルネームは？", 
)
response.response
# Out:
# start_trace
# event_type = query (start)
# event_type = retrieve (start)
# event_type = embedding (start)
# event_type = embedding (end)
# event_type = retrieve (end)
# NodeWithScore(node=Node(text='の子だったが、担当編集から「もっとガチにした方がいい」と指摘を受けて修正していき、たちまち現在の設定となった。 ギターヒーロー ひとりが動画投稿サイトで活動する際に用いるハンドルネーム。ひとりが普段人前に出せないが内面に抱えている承認欲求の象徴とも言えるもので、現実のひとりからはかけ離れた「バスケ部エースの彼氏持ち」や「ラインの友達数は1000人超え」といった設定がつけられている。顔を隠すアングル', doc_id='e3d4ac9f-ffc8-4b69-a46a-c5b8745273bd', embedding=None, doc_hash='4ad06326b3a986a3f99560bcd630c1d0406a4606d3c849bae1ea563d009ef828', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '548410ee-d205-4482-986a-8ddb3678942a'}), score=0.7022262274203019)
# NodeWithScore(node=Node(text='ると、顔を上げ表情も整えればアイドル事務所も狙えるほどのルックスだが、その顔は10秒と持たない。そして自己評価が極めて低く、ひとり自身は外見やスタイルを全く意識していない。 初期設定では普通の可愛い女の子だったが、担当編集から「もっとガチにした方がいい」と指摘を受けて修正していき、たちまち現在の設定となった。 ギターヒーロー ひとりが動画投稿サイトで活動する際に用いるハンドルネーム。ひとりが普段人', doc_id='4e021163-6558-4120-88f7-1d564db1a7d5', embedding=None, doc_hash='510bb7d048c9ae25a3abc9351bbd8f2a9c5c0800244c43663007fe1b280b68f2', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd16b696b-fdf7-41bb-bff7-f4ce9151115e'}), score=0.6886416856027364)
# NodeWithScore(node=Node(text='前に出せないが内面に抱えている承認欲求の象徴とも言えるもので、現実のひとりからはかけ離れた「バスケ部エースの彼氏持ち」や「ラインの友達数は1000人超え」といった設定がつけられている。顔を隠すアングルから撮影された人気バンドのカバー動画を投稿しており、投稿サイトでの登録者数は8万人近く。ぽいずん♡やみのような音楽関係者からも注目を集めている。動画は直樹によって収益化されており、文化祭ライブで壊れた', doc_id='fec1cfdb-b70b-42f4-afdf-760872effdc3', embedding=None, doc_hash='76973ec9fc53b56d1053cae78c3e77381a9868bd7e26beefcc199821aa6bb17c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '4033c5d8-8f8f-46b8-ac0e-1bb88383997c'}), score=0.6387801105156465)
# NodeWithScore(node=Node(text='バンドの動画を密かに撮影するなど注目している。 PAさん 声 - 小岩井ことり ミステリアスな風貌をしたSTARRYの女性PAエンジニア。最終学歴は高校中退。プライベートでは「音戯 アルト（おとぎ アルト）」の名前でバーチャルYouTuberとして活動しており、ゲーム実況動画などを公開している。具体的な名前については作中で言及されず、主に「PAさん」と呼ばれる。 大山 猫々（おおやま ねね） 作中', doc_id='cabd382e-ac7d-4b1d-9095-2a5f8c3ed208', embedding=None, doc_hash='8080d22e74831e52c18585c301e68394b40e20558d665281100595cc9f520b56', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'c60fce83-468b-4d2b-8d61-86b1fa1de1ba'}), score=0.6252516612240472)
# NodeWithScore(node=Node(text='から撮影された人気バンドのカバー動画を投稿しており、投稿サイトでの登録者数は8万人近く。ぽいずん♡やみのような音楽関係者からも注目を集めている。動画は直樹によって収益化されており、文化祭ライブで壊れたギターを新調する費用等に充てられた。 ライブでの現在の自身の実力ではギターヒーローの名前でファンを集めても満足させるだけの演奏ができないというひとりの考えから、正体が「結束バンドの後藤ひとり」であるこ', doc_id='13037695-063d-4cbc-b8c3-ba4bed39c6b3', embedding=None, doc_hash='082aaaaadfca455c46630a2d52c8882237c28f7468c8e83d4c4491a321dee5fe', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c51ddd2-f831-4f9d-a6e9-8bfbf6bc57d5'}), score=0.6148200572533185)
# NodeWithScore(node=Node(text='話す。SICK HACKのライブのゲストに呼ばれたSIDEROSと結束バンドが同じ楽屋を使うことになった際には率先して交流を図るなどフランクな性格。またゲームが好きでオーチューブにて配信、実況も行っている（この際はマスクを外している）。 ひとりと最初にロイン交換をしたが、ひとりがおじさん構文のロインを送ってきたため、心の中でひとりを「おっぢ」「おっぢさん」と呼び、警戒するようになる。また、きくりが', doc_id='46d2e493-bd42-4481-a673-3e7f2de33c62', embedding=None, doc_hash='feed1e9625a5c9a27e70f16097d16d49eb1dc8f4e81cbff0ff368d155e345985', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '4c2b999e-77ca-47a7-98cc-716047922713'}), score=0.6116405048260664)
# NodeWithScore(node=Node(text='教えていなかったが、ひとりの動画投稿サイトでの活動を収益化する手続きをしており（実在の動画サイトであれば本人が18歳以上であるか法定後見人が必要となる）、ひとりがギターを壊してしまった際に広告収入で得たお金を与えている。 目はいつも何か（髪の毛や、ふたりの手など）に隠されていて描かれていない。 会社では窓際族と説明しているが、自宅は金沢八景（横浜市）の戸建てである。 後藤 美智代（ごとう みちよ）', doc_id='22a597fe-dead-4b92-9e28-6a0601ff0da3', embedding=None, doc_hash='d0353c313aa2e99b2583ff0a9f0f6d4cd09b6dc3ef1f74e51709b3ee8c18e156', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '0db841ae-4e5b-45c1-9f0a-a0e29508a688'}), score=0.608379700474727)
# NodeWithScore(node=Node(text='た。 そんな中、演奏以上に最後の最後でのひとりのパフォーマンス失敗が話題と化した文化祭ライブのネットに投稿された映像を見て、それを記事にしようと音楽ライターの「ぽいずん♡やみ」こと佐藤愛子がライブハウスまで結束バンドを取材しに来る。ぽいずん♡やみはそこでのひとりによる演奏のクセを聞いて、ひとりがギターヒーローであることを確信し皆にバラした。ひとり（ギターヒーロー）の腕前なら確実にプロとしても通用す', doc_id='48d7fc96-5aaa-47bf-9c97-ffb0075c90c8', embedding=None, doc_hash='a82ae0747711625cfb7c1eed8e63e0f88454f0dbf1487fd42760784c4579774e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '468e50f1-d082-4033-83a6-e135cc68392e'}), score=0.585825598367401)
# NodeWithScore(node=Node(text='日 / 血液型：B型 音楽情報サイトに寄稿するフリーライター。本名は佐藤 愛子（さとう あいこ）。23歳→24歳。ライターだけで食べていくのは大変なため、「ストレイビート」でアルバイトもしている。 結束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンド', doc_id='fe593f08-dbd4-45c8-a715-1b044a92563a', embedding=None, doc_hash='b77ef4dfb50412ecd1d0d7e9d621cc2f0e2ec66b206cdcaa61422fe259240970', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '3c1a91ba-a3ba-4b02-8d7a-67c6bd1a527d'}), score=0.5855402294581126)
# NodeWithScore(node=Node(text='uTubeでのテレビアニメ連動企画「ギターヒーローへの道」の第4回にて、ひとり役の青山がギターのケースを買いに行く店として登場する。 [脚注の使い方] ^ 雑誌掲載時の扉や単行本の帯にこの言葉がついていることが多く、アニメの公式Twitterなどでもよく使われている。 ^ 観客に受け止めてもらうつもりで檀上からダイブしたが、皆に避けられそのまま床に落下・激突した。 ^ ネットに流れていた映像はひと', doc_id='1e973d6f-12fa-4691-b3ef-ae99fa21172a', embedding=None, doc_hash='07a15fa8991cd4cfad328a6bcc3e446dc5a59bf09ccb1769845671ddee68a02b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'e12a1d71-9f44-47ec-9dcd-0a7d4cce06e3'}), score=0.5846167488735268)
# NodeWithScore(node=Node(text='、SNSでのフォロアー数増減に一喜一憂するなど、実際は小心。その性格を理解している現在のバンドメンバーからは慕われているが、打ち上げに誘われない等ぞんざいに扱われてもいる。 結束バンドのことを知ってわさわざSTARRYに見にいって以後、結束バンドのメンバーとは何かと交流が多くなる。アドバイスを送る、迷子のひとりをSIDEROSメンバーの説得もあってスタジオに誘う、ひとりと動画を合同で撮影する、自動', doc_id='3a6a60c8-796d-4816-bce8-4d89b8ab1893', embedding=None, doc_hash='d06ee4da0e6c221f4d7e9abb36923267da2413e1ec37709a08007eca48b2445c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'ad5615bb-cde4-4b02-a6ee-33bdcb35be9d'}), score=0.5825947608084242)
# NodeWithScore(node=Node(text='女子学生服などを鑑賞用に所持していたりする。また涙もろい。 ひとりのギターヒーローとしての正体まではわからなかったものの、ひとりのギタリストとしての才能にもいち早く気づいており、ひとりを中心にした結束バンドの動画を密かに撮影するなど注目している。 PAさん 声 - 小岩井ことり ミステリアスな風貌をしたSTARRYの女性PAエンジニア。最終学歴は高校中退。プライベートでは「音戯 アルト（おとぎ ア', doc_id='9624f4f2-e53d-40f5-8e40-9ddaf5118337', embedding=None, doc_hash='407f9383e466c6fb2c2398b375714487f035eb13ab23ab0a795db6783e8afab3', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'd93358bc-c320-4999-afa3-ac33bfebfc59'}), score=0.5718210686596212)
# NodeWithScore(node=Node(text='にも採用されたことがあるが、本人曰く「父さんのバンドはそこがピークでその後は鳴かず飛ばず」のちに妻となる美智代に「就職しなかったら別れる」と言われて辞めたという生々しい経験を語って聞かせた。 本人には教えていなかったが、ひとりの動画投稿サイトでの活動を収益化する手続きをしており（実在の動画サイトであれば本人が18歳以上であるか法定後見人が必要となる）、ひとりがギターを壊してしまった際に広告収入で得', doc_id='ba9604f5-1668-4275-ba93-bd71c3f6bcdd', embedding=None, doc_hash='7384ae1029b65ea689243f9b263fe6949c08c1ffb140d926ead776d88ac07d3e', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '05c22381-592d-4767-ad02-32e0cd0529cf'}), score=0.5701957456976428)
# NodeWithScore(node=Node(text='虹夏に「中毒」と言われるほどSNSの、特に写真掲載に熱心。苦に思っているわけではないが、SNSや友人との話題合わせなどにかなり労力を割いている。バンドでも他の3人がインドア派なのに対し、海水浴などアウトドアでの遊びにも積極的。運動神経も良く、部活の助っ人を頼まれることが多い。また、勉強等も無難にこなす一方で、自身をひとりやリョウと比較して特別秀でた部分のない平凡な人間だとも思っている。自身の「郁代', doc_id='d8612fe3-96ca-40bb-b3fd-4e79140c7c6f', embedding=None, doc_hash='13b6e73d20335c6068639bfa7da6aaefaa6581b102cd5c6ed52858f7d77db5cd', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '44c47c85-3372-4f4c-9b7c-596833e41023'}), score=0.5683843413220522)
# NodeWithScore(node=Node(text='いることが多く、アニメの公式Twitterなどでもよく使われている。 ^ 観客に受け止めてもらうつもりで檀上からダイブしたが、皆に避けられそのまま床に落下・激突した。 ^ ネットに流れていた映像はひとりのダイブの場面だけで、結束バンドの演奏シーンは入っていなかった。 ^ 作中の具体的な年月としては、ひとりの高校入学が2017年4月の出来事と設定されている。 ^ ジャンルとしてはエモロックだが、これ', doc_id='f5b9adb3-1eed-4239-a306-648dea05891a', embedding=None, doc_hash='5b29933fdec4c0a03bd4706b87b8a2c89de35e120ac6a0eca18521d3bd19a924', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '50d3cae1-a14c-4047-92c5-ae1b23e3a9bd'}), score=0.5681287525861196)
# NodeWithScore(node=Node(text='協しない。一方で、人気・知名度などにおいて自分が優位であると（他人を見下しているのではなく、自分の価値をアピールするために）主張したがり、勝ち気で素直さに欠けた言動も多い。あくびからは「コミュニケーション下手」と評され、きくりには「（バンドの）メンバー以外友達いない」と言われている、「ひとりとはタイプの違うコミュ障」。また、いつも自信ありげな態度を見せる一方で、ライブの前に緊張で3日くらい眠れない', doc_id='455bbe96-4197-4ef7-8835-a7314b2a81ec', embedding=None, doc_hash='368a254ae40f685c7a272d13dfe3770e15346197dfb24352e9751157030a9b4c', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '967e6a2f-0ea3-4f34-a810-8fed56b8eab9'}), score=0.5591418524968486)
# NodeWithScore(node=Node(text='そもそもない）など、少しずつではあるが変わりつつある。 ^ プロのギタリストになってテレビでインタビューされた時には何を答えるか考える、逆に人生へ失敗してニートに落ちぶれた自分を想像するなど。 ^ バンドの皆に正体を知られてからは、そういった設定の妄言投稿はやめている。 ^ 当初は結束バンドメンバーにも秘密にされていたが、2度目のライブ中に虹夏のみが気付き、後にぽいずん♡やみによる指摘を経てリョウ', doc_id='81fb347c-8251-42a3-96e8-fa2af5b0c4f3', embedding=None, doc_hash='704861b20b48eb44104153f3a7d7e9ebc0b2d5cb1c1de56f3d9acb2d6e35cc5d', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: 'fe87bd17-391d-4a30-bda8-b7f3166994af'}), score=0.5560818565074701)
# NodeWithScore(node=Node(text='束バンドの取材にSTARRYを訪れ、演奏の癖からひとりとギターヒーローが同一人物であることを見抜く。ギターヒーローの動画に注目する1人で、その実力を既にプロでも通用すると評価している。一方で結束バンドについては「高校生にしたらレベルはまぁ高いと思う」としつつも、その活動姿勢を「ガチじゃない」「本気でプロを目指しているバンドに見えない」と評し「こんなところでうだうだやってると才能腐っちゃいますよ」と', doc_id='d2e4efc2-0308-46ed-8ae8-046216b0add1', embedding=None, doc_hash='b5b68c75508e09c2ab94381ec5596e62cb4040a1e801a35ea12a0811acaecfd6', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '690071fd-aa48-4d24-b452-b215f6c0e307'}), score=0.5522439408006017)
# NodeWithScore(node=Node(text='取ったことで周囲から見直され、「一番になれば世界が認めてくれる」「もっと好きな事で一番になりたい」という思いからバンドを始めた過去を持つ。それゆえ順位や数字に対するこだわり、上昇意欲が一倍強く努力も妥協しない。一方で、人気・知名度などにおいて自分が優位であると（他人を見下しているのではなく、自分の価値をアピールするために）主張したがり、勝ち気で素直さに欠けた言動も多い。あくびからは「コミュニケーシ', doc_id='04551fed-e1ea-4d55-9615-d106bef5edfb', embedding=None, doc_hash='9f4d4f55f1df12c4f08b5b9754067bfdebeb7ed60e2eb3c445f7fb4c06e4161b', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '37309569-c09c-4c43-99bd-3950a824d0a0'}), score=0.5517351168491301)
# NodeWithScore(node=Node(text='ャラを作成している。明るく前向きな歌詞にコンプレックスを持つひとりが作詞を担当しているため、楽曲はネガティブなものが多い。 メンバーの苗字（後藤、伊地知、山田、喜多）はいずれもアジカンのメンバーの苗字に由来し、誕生日は対応するメンバーの誕生日を逆さまにしたものとなっている。 後藤 ひとり（ごとう ひとり） 声 - 青山吉能 誕生日：2月21日 / 身長：156cm / 体重：50kg / 血液型：', doc_id='3063ecec-b281-4452-bd92-50fb212f4fe4', embedding=None, doc_hash='1c109399621b5042deb37fbabc1c3600239297b9a3c80539f226cf302a830f74', extra_info=None, node_info={'start': 0, 'end': 200, '_node_type': <NodeType.TEXT: '1'>}, relationships={<DocumentRelationship.SOURCE: '1'>: '425041b2-0544-4c4a-b35f-14add76a8455'}), score=0.5498568471688201)
# event_type = synthesize (start)
# event_type = llm (start)
# event_type = llm (end)
# event_type = synthesize (end)
# event_type = query (end)
# **********
# Trace: query
#     |_query ->  1.073415 seconds
#       |_retrieve ->  0.079889 seconds
#         |_embedding ->  0.021901 seconds
#       |_synthesize ->  0.99275 seconds
#         |_llm ->  0.95091 seconds
# **********
# end_trace
# '「ストレイビート」'
