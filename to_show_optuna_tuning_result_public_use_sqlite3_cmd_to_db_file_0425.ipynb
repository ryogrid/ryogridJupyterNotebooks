# %% [markdown]
# <a href="https://colab.research.google.com/github/ryogrid/ryogridJupyterNotebooks/blob/master/to_show_optuna_tuning_result_public_use_sqlite3_cmd_to_db_file_0425.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import itertools
data = [0,1,2,3,4]
rslt = []
for comb_len in range(1,5):
  rslt.extend(list(itertools.combinations(data, comb_len)))
#for elem in rslt:
#  print(str(1 in elem))
print(len(rslt))
print(rslt)

# %%
# !apt-get install -y sqlite3

# %%
# !sqlite3 fxsystrade.db 'SELECT * FROM trials'
# Out:
# 1|1|RUNNING||2019-04-23 05:05:02.777422|
# 2|1|COMPLETE|0.453376149675304|2019-04-23 05:05:02.780119|2019-04-23 05:13:30.619300
# 3|1|RUNNING||2019-04-23 05:05:02.791236|
# 4|1|COMPLETE|0.550241776393467|2019-04-23 05:05:02.792330|2019-04-23 05:11:04.955005
# 5|1|COMPLETE|0.531814417182422|2019-04-23 05:05:02.793730|2019-04-23 05:14:08.836502
# 6|1|RUNNING||2019-04-23 05:05:02.779850|
# 7|1|COMPLETE|0.63345667730253|2019-04-23 05:05:02.793260|2019-04-23 05:08:54.131965
# 8|1|COMPLETE|0.642728762509149|2019-04-23 05:05:02.792829|2019-04-23 05:11:35.300722
# 9|1|COMPLETE|0.379878290149107|2019-04-23 05:05:02.792001|2019-04-23 05:39:14.391030
# 10|1|RUNNING||2019-04-23 05:05:02.793030|
# 11|1|RUNNING||2019-04-23 05:05:02.792603|
# 12|1|COMPLETE|0.503265436092761|2019-04-23 05:05:02.794459|2019-04-23 05:21:03.818768
# 13|1|COMPLETE|0.516156915101268|2019-04-23 05:08:54.459160|2019-04-23 06:48:58.892403
# ...

# %%
# !nvidia-smi
# Out:
# Tue Apr 23 22:54:07 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    42W /  70W |    415MiB / 15079MiB |     60%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !top

# %%
# %cd fx_systrade
# Out:
# /content/gdrive/My Drive/gcolab_workdir_xgboost/fx_systrade

# %%
# !git config --global user.email "ryo.contact@gmail.com"
# !git config --global user.name "Ryo Kanbayashi"
# !git commit fxsystrade.db -m "backup"
# Out:
# [for_try_keras_trade_learning_at_google_colab 980afbe] backup
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 fxsystrade.db

# %%
from google import colab
colab.drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive/gcolab_workdir_xgboost"
# Out:
# /content/gdrive/My Drive/gcolab_workdir_xgboost

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot open directory '.': Transport endpoint is not connected
