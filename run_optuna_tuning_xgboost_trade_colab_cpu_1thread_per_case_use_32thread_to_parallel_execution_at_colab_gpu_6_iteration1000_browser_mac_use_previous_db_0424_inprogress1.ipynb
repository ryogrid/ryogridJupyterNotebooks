# %% [markdown]
# <a href="https://colab.research.google.com/github/ryogrid/ryogridJupyterNotebooks/blob/master/run_optuna_tuning_xgboost_trade_colab_cpu_1thread_per_case_use_32thread_to_parallel_execution_at_colab_gpu_6_iteration1000_browser_mac_use_previous_db_0424_inprogress1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /root/
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install ta-lib
# Out:
# /root
# --2019-04-23 22:17:10--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 216.105.38.13
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|216.105.38.13|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2019-04-23 22:17:10--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 216.105.38.13
# Reusing existing connection to prdownloads.sourceforge.net:80.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cfhcable.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# ...

# %%
from google import colab
colab.drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/gcolab_workdir_xgboost/'
# Out:
# /content/gdrive/My Drive/gcolab_workdir_xgboost

# %%
# !pip uninstall -y xgboost
# !pip install xgboost
# Out:
# Uninstalling xgboost-0.82:
#   Successfully uninstalled xgboost-0.82
# ...
#   Using cached https://files.pythonhosted.org/packages/6a/49/7e10686647f741bd9c8918b0decdb94135b542fe372ca1100739b8529503/xgboost-0.82-py2.py3-none-manylinux1_x86_64.whl
# ...

# %%
# %cd '/content/gdrive/My Drive/gcolab_workdir_xgboost/'
# !rm -rf fx_systrade
# !git clone -b for_try_keras_trade_learning_at_google_colab https://github.com/ryogrid/fx_systrade.git --depth 1
# Out:
# /content/gdrive/My Drive/gcolab_workdir_xgboost
# Cloning into 'fx_systrade'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 2), reused 2 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
# !cp tr_input_mat.pickle fx_systrade/
# !cp tr_angle_mat.pickle fx_systrade/

# %%
# %cd 'fx_systrade'
# Out:
# /content/gdrive/My Drive/gcolab_workdir_xgboost/fx_systrade

# %%
# !pip install pytz
# !pip install optuna

# %%
#!optuna create-study --study 'fxsystrade' --storage 'sqlite:///../fxsystrade.db'

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.7.1
# alabaster                0.7.12
# albumentations           0.1.12
# alembic                  1.0.9
# altair                   2.4.1
# astor                    0.7.1
# astropy                  3.0.5
# atari-py                 0.1.7
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.6
# autograd                 1.2
# Babel                    2.6.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.134
# botocore                 1.12.134
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.0
# ...

# %%
import xgboost_trade_colab_gpu
xgboost_trade_colab_gpu.run_script("CHANGE_TO_PARAM_TUNING_MODE")
xgboost_trade_colab_gpu.set_tune_trial_num(1000)
xgboost_trade_colab_gpu.set_optuna_special_parallel_num(32)
xgboost_trade_colab_gpu.set_enable_db_at_tune()
xgboost_trade_colab_gpu.run_script("TRAIN_GPU")
#xgboost_trade_colab_gpu.run_script("TRADE_COLAB_CPU")
# Out:
# data size of rates: 836678
# num of rate datas for tarin: 522579
# input features sets for tarin: 208952
# [W 2019-04-23 22:18:42,114] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# [W 2019-04-23 22:18:42,322] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# [W 2019-04-23 22:18:42,404] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# [W 2019-04-23 22:18:42,490] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# [W 2019-04-23 22:18:42,656] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# [W 2019-04-23 22:18:42,862] The range of parameter `vorarity_thresh` is not divisible by `q`, and is replaced by [0.01, 0.29000000000000004].
# ...
